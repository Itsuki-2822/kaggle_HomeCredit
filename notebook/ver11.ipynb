# %%
# 標準ライブラリ
import gc
import os
import pickle
import random
import sys
import warnings
from itertools import combinations, permutations
from pathlib import Path
import pytz

# サードパーティのライブラリ
import category_encoders as ce
import joblib
import lightgbm as lgb
import numpy as np
import pandas as pd
import polars as pl
import scipy as sp
import seaborn as sns
import torch
import xgboost as xgb
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from dateutil.relativedelta import relativedelta
from sklearn.base import BaseEstimator, ClassifierMixin, RegressorMixin
from sklearn.impute import KNNImputer
from sklearn.metrics import f1_score, log_loss, matthews_corrcoef, roc_auc_score
from sklearn.model_selection import (GroupKFold, KFold, StratifiedKFold,
                                     StratifiedGroupKFold, TimeSeriesSplit,
                                     train_test_split)
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from tqdm.auto import tqdm

import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

import glob
import datetime

# %%
class CFG:
    home_directory = os.path.expanduser('~/kaggle_HomeCredit/')
    kaggle_directory = os.path.expanduser('/kaggle/input/home-credit-credit-risk-model-stability/')
    
    train_data_path = os.path.join(home_directory, 'train/')
    test_data_path = os.path.join(home_directory, 'test/')
    
    OOF_DATA_PATH = Path(home_directory) / 'oof'
    MODEL_DATA_PATH = Path(home_directory) / 'models'
    SUB_DATA_PATH = Path(home_directory) / 'submission'

    def __init__(self):
        self.create_directories()
    
    def create_directories(self):
        for path in [self.OOF_DATA_PATH, self.MODEL_DATA_PATH, self.SUB_DATA_PATH]:
            path.mkdir(parents=True, exist_ok=True)
    
    
    VER = 11
    AUTHOR = 'Mira'
    COMPETITION = 'HomeCredit'

    METHOD_LIST = ['lightgbm','catboost']
    seed = 28
    n_folds = 5
    target_col = 'target'
    metric = 'auc'
    
    metric_maximize_flag = True
    num_boost_round = 500
    early_stopping_round = 200
    verbose = 25
    classification_lgb_params = {
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': 0.05,
        'seed': seed,
        #"device_type": "gpu",
    }
    classification_xgb_params = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': 0.05,
        'random_state': seed,
        "tree_method": "gpu_hist",
    }

    classification_cat_params = {
        'learning_rate': 0.05,
        'iterations': num_boost_round,
        'random_seed': seed,
        #"task_type": "GPU",
    }
    model_weight_dict = {'lightgbm': 0.5,'catboost':0.5}
    

class is_kaggle:
    def __init__(self, Kaggle):
        if Kaggle == "Yes":
            self.path = Path(CFG.kaggle_directory)
            CFG.MODEL_DATA_PATH = Path('/kaggle/input/04191103/models')
        else:
            self.path = Path(CFG.home_directory)
            CFG.MODEL_DATA_PATH = Path(CFG.home_directory) / 'models'

def create_timestamped_file():
    tz_tokyo = pytz.timezone('Asia/Tokyo')
    now = datetime.datetime.now(tz=tz_tokyo)
    filename = now.strftime('%m%d-%H%M') + '.txt'
    full_path = CFG.MODEL_DATA_PATH / filename
    full_path.touch()

#create_timestamped_file()
cfg_instance = CFG()      
selector = is_kaggle("No")

# %%
class Pipeline:
    @staticmethod
    def set_table_dtypes(df):
        for col in df.columns:
            if col in ["case_id", "WEEK_NUM", "num_group1", "num_group2"]:
                df = df.with_columns(pl.col(col).cast(pl.Int32))
            elif col in ["date_decision"]:
                df = df.with_columns(pl.col(col).cast(pl.Date))
            elif col[-1] in ("P", "A"):
                df = df.with_columns(pl.col(col).cast(pl.Float64))
            elif col[-1] in ("M",):
                df = df.with_columns(pl.col(col).cast(pl.String))
            elif col[-1] in ("D",):
                df = df.with_columns(pl.col(col).cast(pl.Date))            

        return df
    
    @staticmethod
    def handle_dates(df):
        for col in df.columns:
            if col[-1] in ("D",):
                df = df.with_columns(pl.col(col) - pl.col("date_decision"))
                df = df.with_columns(pl.col(col).dt.total_days())
                df = df.with_columns(pl.col(col).cast(pl.Float32))
                
        df = df.drop("date_decision", "MONTH")

        return df
    
    @staticmethod
    def filter_cols(df):
        for col in df.columns:
            if col not in ["target", "case_id", "WEEK_NUM"]:
                isnull = df[col].is_null().mean()

                if isnull > 0.95:
                    df = df.drop(col)

        for col in df.columns:
            if (col not in ["target", "case_id", "WEEK_NUM"]) & (df[col].dtype == pl.String):
                freq = df[col].n_unique()

                if (freq == 1) | (freq > 200):
                    df = df.drop(col)

        return df

# %%
class Aggregator:
    @staticmethod
    def num_expr(df):
        cols = [col for col in df.columns if col[-1] in ("P", "A")]

        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]
        expr_min = [pl.min(col).alias(f"min_{col}") for col in cols]
        expr_mean = [pl.mean(col).alias(f"mean_{col}") for col in cols]
        expr_std = [pl.std(col).alias(f"std_{col}") for col in cols] 
        expr_mean = [pl.mean(col).alias(f"mean_{col}") for col in cols]

        #moving_average = [pl.col(col).rolling_mean(3).alias(f'{col}_moving_average') for col in cols]
        #lag_feature = pl.col(col).shift(1).alias(f'{col}_lag_1')
        #growth_rate = (pl.col(col).diff(1) / pl.col(col).shift(1) * 100).alias(f'{col}_growth_rate')

        return expr_max + expr_min + expr_mean + expr_std

    @staticmethod
    def date_expr(df):
        cols = [col for col in df.columns if col[-1] in ("D",)]

        expr_min = [pl.min(col).alias(f"min_{col}") for col in cols]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_min + expr_max

    @staticmethod
    def str_expr(df):
        cols = [col for col in df.columns if col[-1] in ("M",)]
        
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max

    @staticmethod
    def other_expr(df):
        cols = [col for col in df.columns if col[-1] in ("T", "L")]
        
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max
    
    @staticmethod
    def count_expr(df):
        cols = [col for col in df.columns if "num_group" in col]

        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max

    @staticmethod
    def get_exprs(df):
        exprs = Aggregator.num_expr(df) + \
                Aggregator.date_expr(df) + \
                Aggregator.str_expr(df) + \
                Aggregator.other_expr(df) + \
                Aggregator.count_expr(df)

        return exprs

# %%
def read_file(path, depth=None):
    df = pl.read_parquet(path)
    df = df.pipe(Pipeline.set_table_dtypes)
    
    if depth in [1, 2]:
        df = df.group_by("case_id").agg(Aggregator.get_exprs(df))
    
    return df

def read_files(regex_path, depth=None):
    chunks = []
    for path in glob.glob(str(regex_path)):
        df = pl.read_parquet(path)
        df = df.pipe(Pipeline.set_table_dtypes)
        
        if depth in [1, 2]:
            df = df.group_by("case_id").agg(Aggregator.get_exprs(df))
        
        chunks.append(df)
        
    df = pl.concat(chunks, how="vertical_relaxed")
    df = df.unique(subset=["case_id"])
    
    return df

# %%
def feature_eng(df_base, depth_0, depth_1, depth_2):
    df_base = (
        df_base
        .with_columns(
            month_decision = pl.col("date_decision").dt.month(),
            weekday_decision = pl.col("date_decision").dt.weekday(),
        )
    )
        
    for i, df in enumerate(depth_0 + depth_1 + depth_2):
        df_base = df_base.join(df, how="left", on="case_id", suffix=f"_{i}")
        
    df_base = df_base.pipe(Pipeline.handle_dates)
    
    return df_base

# %%
def to_pandas(df, cat_cols=None):
    df_data = df.to_pandas()

    bool_cols = df_data.select_dtypes('bool').columns
    df_data[bool_cols] = df_data[bool_cols].astype(int)

    if cat_cols is None:
        cat_cols = list(df_data.select_dtypes("object").columns)
    
    df_data[cat_cols] = df_data[cat_cols].astype("category")
    
    return df_data, cat_cols

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        if str(col_type)=="category":
            continue
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            continue
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
ROOT = selector.path
TRAIN_DIR       = ROOT / "parquet_files/train"
TEST_DIR        = ROOT / "parquet_files/test"
SAMPLE_SUB = ROOT / "sample_submission.csv"

# %%
train_data_store = {
    "df_base": read_file(TRAIN_DIR / "train_base.parquet"),
    "depth_0": [
        read_file(TRAIN_DIR / "train_static_cb_0.parquet"),
        read_files(TRAIN_DIR / "train_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TRAIN_DIR / "train_applprev_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_a_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_c_1.parquet", 1),
        read_files(TRAIN_DIR / "train_credit_bureau_a_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_credit_bureau_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_other_1.parquet", 1),
        read_file(TRAIN_DIR / "train_person_1.parquet", 1),
        read_file(TRAIN_DIR / "train_deposit_1.parquet", 1),
        read_file(TRAIN_DIR / "train_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TRAIN_DIR / "train_credit_bureau_b_2.parquet", 2),
        read_files(TRAIN_DIR / "train_credit_bureau_a_2_*.parquet", 2),
    ]
}

# %%
test_data_store = {
    "df_base": read_file(TEST_DIR / "test_base.parquet"),
    "depth_0": [
        read_file(TEST_DIR / "test_static_cb_0.parquet"),
        read_files(TEST_DIR / "test_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TEST_DIR / "test_applprev_1_*.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_a_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_b_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_c_1.parquet", 1),
        read_files(TEST_DIR / "test_credit_bureau_a_1_*.parquet", 1),
        read_file(TEST_DIR / "test_credit_bureau_b_1.parquet", 1),
        read_file(TEST_DIR / "test_other_1.parquet", 1),
        read_file(TEST_DIR / "test_person_1.parquet", 1),
        read_file(TEST_DIR / "test_deposit_1.parquet", 1),
        read_file(TEST_DIR / "test_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TEST_DIR / "test_credit_bureau_b_2.parquet", 2),
        read_files(TEST_DIR / "test_credit_bureau_a_2_*.parquet", 2),
    ]
}

# %%
def lightgbm_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list):
    cat_features = x_train.select_dtypes('category').columns.tolist()
    lgb_train = lgb.Dataset(x_train, y_train,categorical_feature=cat_features)
    lgb_valid = lgb.Dataset(x_valid, y_valid,categorical_feature=cat_features)
    model = lgb.train(
                params = CFG.classification_lgb_params,
                train_set = lgb_train,
                num_boost_round = CFG.num_boost_round,
                valid_sets = [lgb_train, lgb_valid],
                #feval = CFG.metric,
                callbacks=[lgb.early_stopping(stopping_rounds=CFG.early_stopping_round,
                                              verbose=CFG.verbose)]
            )
    valid_pred = model.predict(x_valid)
    
    importance_df = pd.DataFrame({
        'feature': features,
        'importance': model.feature_importance(importance_type='gain')
    })
    importance_df['importance'] = importance_df['importance'] / np.sum(importance_df['importance'])
    importance_df = importance_df.sort_values(by='importance', ascending=False)
    print(importance_df)
    return model, valid_pred
def xgboost_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list):
    xgb_train = xgb.DMatrix(data=x_train, label=y_train)
    xgb_valid = xgb.DMatrix(data=x_valid, label=y_valid)
    model = xgb.train(
                CFG.classification_xgb_params,
                dtrain = xgb_train,
                num_boost_round = CFG.num_boost_round,
                evals = [(xgb_train, 'train'), (xgb_valid, 'eval')],
                early_stopping_rounds = CFG.early_stopping_round,
                verbose_eval = CFG.verbose,
                #feval = CFG.metric,
                maximize = CFG.metric_maximize_flag,
        )
    valid_pred = model.predict(xgb.DMatrix(x_valid))
    return model, valid_pred
def catboost_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list):
    cat_features = x_train.select_dtypes('category').columns.tolist()
    cat_train = Pool(data=x_train, label=y_train,cat_features=cat_features)
    cat_valid = Pool(data=x_valid, label=y_valid,cat_features=cat_features)
    model = CatBoostClassifier(**CFG.classification_cat_params)
    model.fit(cat_train,
              eval_set = [cat_valid],
              early_stopping_rounds = CFG.early_stopping_round,
              verbose = CFG.verbose,
              use_best_model = True)
    valid_pred = model.predict_proba(x_valid)[:, 1]
    return model, valid_pred

# %%
def gradient_boosting_model_cv_training(method: str, train_df: pd.DataFrame, features: list):
    features = [col for col in train_df.columns if col != CFG.target_col and col not in ["case_id", "WEEK_NUM"]]
    weeks = train_df["WEEK_NUM"]
    X = train_df.drop(columns=["target", "case_id", "WEEK_NUM"])
    y = train_df["target"]
    
    oof_predictions = np.zeros(len(train_df))
    oof_fold = np.zeros(len(train_df))
    cv = StratifiedGroupKFold(n_splits=CFG.n_folds, shuffle=True, random_state=CFG.seed)
    for fold, (train_index, valid_index) in enumerate(cv.split(X, y, groups=weeks)):
        print('-'*50)
        print(f'{method} training fold {fold+1}')

        x_train = train_df[features].iloc[train_index]
        y_train = train_df[CFG.target_col].iloc[train_index]
        x_valid = train_df[features].iloc[valid_index]
        y_valid = train_df[CFG.target_col].iloc[valid_index]
        if method == 'lightgbm':
            model, valid_pred = lightgbm_training(x_train, y_train, x_valid, y_valid, features)
        if method == 'xgboost':
            model, valid_pred = xgboost_training(x_train, y_train, x_valid, y_valid, features)
        if method == 'catboost':
            model, valid_pred = catboost_training(x_train, y_train, x_valid, y_valid, features)

        pickle.dump(model, open(CFG.MODEL_DATA_PATH / f'{method}_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'wb'))

        oof_predictions[valid_index] = valid_pred
        oof_fold[valid_index] = fold + 1
        del x_train, x_valid, y_train, y_valid, model, valid_pred
        gc.collect()

    score = roc_auc_score(train_df[CFG.target_col], oof_predictions)
    print(f'{method} our out of folds CV f1score is {score}')

    oof_df = pd.DataFrame({CFG.target_col: train_df[CFG.target_col], f'{method}_prediction': oof_predictions, 'fold': oof_fold})
    oof_df.to_csv(CFG.OOF_DATA_PATH / f'oof_{method}_seed{CFG.seed}_ver{CFG.VER}.csv', index = False)

def Learning(input_df: pd.DataFrame, features: list):
    for method in CFG.METHOD_LIST:
        gradient_boosting_model_cv_training(method, input_df, features)

# %%
def unified_inference(method: str, x_test: pd.DataFrame):
    test_pred = np.zeros(len(x_test))
    for fold in range(CFG.n_folds):
        model_path = CFG.MODEL_DATA_PATH / f'{method}_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl'
        model = pickle.load(open(model_path, 'rb'))

        if method == 'lightgbm':
            pred = model.predict(x_test)
        elif method == 'xgboost':
            pred = model.predict(xgb.DMatrix(x_test))
        elif method == 'catboost':
            pred = model.predict_proba(x_test)[:, 1]
        else:
            raise ValueError(f"Unsupported method: {method}")

        test_pred += pred
    
    return test_pred / CFG.n_folds

def gradient_boosting_model_inference(method: str, test_df: pd.DataFrame, features: list):
    x_test = test_df[features]
    test_pred = unified_inference(method, x_test)
    return test_pred

def Predicting(input_df: pd.DataFrame, features: list):
    output_df = input_df.copy()
    output_df['pred_prob'] = 0
    for method in CFG.METHOD_LIST:
        output_df[f'{method}_pred_prob'] = gradient_boosting_model_inference(method, input_df, features)
        output_df['pred_prob'] += CFG.model_weight_dict[method] * output_df[f'{method}_pred_prob']
    return output_df

# %%
def target_enc(df,test,col):
    features = [col for col in df.columns if col != CFG.target_col]
    kf = KFold(n_splits=CFG.n_folds,shuffle=True,random_state = CFG.seed)
    encoded_features = []

    for train_idx, val_idx in kf.split(df):
        X_train, X_valid = df[features].iloc[train_idx], df[features].iloc[val_idx]
        y_train = df[CFG.target_col].iloc[train_idx]

        target_encoder = ce.TargetEncoder()
        target_encoder.fit(X_train[col], y_train)

        X_valid[f'{col}_target_Encoded'] = target_encoder.transform(X_valid[col])
        encoded_features.append(X_valid)


    encoded_df = pd.concat(encoded_features).sort_index()
    df[f'{col}_target_Encoded'] = encoded_df[f'{col}_target_Encoded']
    
    target_encoder = ce.TargetEncoder()
    target_encoder.fit(df[[col]], df[CFG.target_col])

    test[f'{col}_target_Encoded'] = target_encoder.transform(test[[col]])
    
    return df, test

def encoder(df, test):
    object_columns = [col for col in df.columns if df[col].dtype.name == 'object' or df[col].dtype.name == 'category']
    
    bool_columns = [col for col in df.columns if df[col].dtype == 'bool']

    for col in object_columns:
        df, test = target_enc(df, test, col)
        
    for col in bool_columns:
        df[col] = df[col].astype(int)
        test[col] = test[col].astype(int)

    df.drop(object_columns, axis=1, inplace=True)
    test.drop(object_columns, axis=1, inplace=True)
        
    return df, test


def preprocess(df,test):
    df,test = encoder(df,test)
    features = [col for col in df.columns if col != CFG.target_col and col not in ["case_id", "WEEK_NUM"]]
    
    return df,test,features

# %%
class DataPreprocessor:
    def __init__(self, df):
        self.df = df

    def select_numerical_columns(self):
        return self.df.select_dtypes(exclude='category').columns

    def calculate_nan_groups(self, nums):
        nans_df = self.df[nums].isna()
        nans_groups = {}
        for col in nums:
            cur_group = nans_df[col].sum()
            nans_groups.setdefault(cur_group, []).append(col)
        del nans_df
        gc.collect()
        return nans_groups

    def reduce_group(self, groups):
        use = []
        for group in groups:
            max_unique = 0
            selected_col = group[0]
            for col in group:
                unique_count = self.df[col].nunique()
                if unique_count > max_unique:
                    max_unique = unique_count
                    selected_col = col
            use.append(selected_col)
        print('Use these:', use)
        return use

    def group_columns_by_correlation(self, matrix, threshold=0.8):
        correlation_matrix = matrix.corr()
        cols = list(matrix.columns)
        groups = []

        while cols:
            base_col = cols.pop(0)
            group = [base_col]
            correlated_cols = [base_col]

            for col in cols:
                if correlation_matrix.loc[base_col, col] >= threshold:
                    group.append(col)
                    correlated_cols.append(col)

            groups.append(group)
            cols = [c for c in cols if c not in correlated_cols]
        
        return groups

    def process_columns(self):
        nums = self.select_numerical_columns()
        nans_groups = self.calculate_nan_groups(nums)
        uses = []

        for count, columns in nans_groups.items():
            if len(columns) > 1:
                grps = self.group_columns_by_correlation(self.df[columns])
                uses += self.reduce_group(grps)
            else:
                uses += columns

            print('####### NAN count =', count)
        
        print('Selected numerical columns:', uses)
        return uses

    def update_dataframe(self):
        uses = self.process_columns()
        uses += list(self.df.select_dtypes(include='category').columns)
        print('Total columns used:', len(uses))
        self.df = self.df[uses]

# %%
def feature_engg(df):
    exclude_prefixes = ['max_', 'min_', 'mean_', 'std_']
    exclude_columns = ["case_id", "WEEK_NUM", CFG.target_col]

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

    features = [col for col in numeric_cols
                if col not in exclude_columns and not any(col.startswith(prefix) for prefix in exclude_prefixes)]
    
    for feature in features:
        df[f'{feature}_moving_average'] = df[feature].rolling(window=3).mean()
        df[f'{feature}_lag_1'] = df[feature].shift(2)
        df[f'{feature}_growth_rate'] = df[feature].pct_change() * 100
    return df

# %%
df_train = feature_eng(**train_data_store)
print("train data shape:\t", df_train.shape)
del train_data_store
gc.collect()
df_train = df_train.pipe(Pipeline.filter_cols)
df_train, cat_cols = to_pandas(df_train)
df_train = feature_engg(df_train)
df_train = reduce_mem_usage(df_train)
print("train data shape:\t", df_train.shape)


preprocessor = DataPreprocessor(df_train)
preprocessor.update_dataframe()
print("train data shape:\t", df_train.shape)
# Out:
# train data shape:	 (1526659, 738)
# Memory usage of dataframe is 10286.23 MB
# Memory usage after optimization is: 4867.24 MB
# Decreased by 52.7%
# train data shape:	 (1526659, 1005)
# Use these: ['case_id', 'WEEK_NUM', 'target', 'month_decision', 'weekday_decision', 'credamount_770A', 'applicationcnt_361L', 'applications30d_658L', 'applicationscnt_1086L', 'applicationscnt_464L', 'applicationscnt_867L', 'clientscnt_1022L', 'clientscnt_100L', 'clientscnt_1071L', 'clientscnt_1130L', 'clientscnt_157L', 'clientscnt_257L', 'clientscnt_304L', 'clientscnt_360L', 'clientscnt_493L', 'clientscnt_533L', 'clientscnt_887L', 'clientscnt_946L', 'deferredmnthsnum_166L', 'disbursedcredamount_1113A', 'downpmt_116A', 'homephncnt_628L', 'isbidproduct_1095L', 'mobilephncnt_593L', 'numactivecreds_622L', 'numactivecredschannel_414L', 'numactiverelcontr_750L', 'numcontrs3months_479L', 'numnotactivated_1143L', 'numpmtchanneldd_318L', 'numrejects9m_859L', 'sellerplacecnt_915L', 'max_mainoccupationinc_384A', 'min_birth_259D', 'max_num_group1_9']
# ####### NAN count = 0
# Use these: ['assignmentdate_238D', 'assignmentdate_238D_lag_1']
# ####### NAN count = 1389663
# Use these: ['assignmentdate_4527235D', 'pmtaverage_4527227A', 'pmtcount_4527229L', 'assignmentdate_4527235D_lag_1', 'pmtaverage_4527227A_lag_1']
# ####### NAN count = 1411681
# Use these: ['birthdate_574D', 'birthdate_574D_lag_1']
# ####### NAN count = 918788
# Use these: ['contractssum_5085716L']
# ####### NAN count = 1369330
# Use these: ['dateofbirth_337D', 'days180_256L', 'days30_165L', 'days360_512L', 'firstquarter_103L', 'fourthquarter_440L', 'secondquarter_766L', 'thirdquarter_1082L', 'max_debtoutstand_525A', 'max_debtoverdue_47A', 'min_refreshdate_3813885D', 'max_refreshdate_3813885D']
# ####### NAN count = 140968
# Use these: ['pmtaverage_3A', 'pmtaverage_3A_lag_1']
# ####### NAN count = 1383070
# Use these: ['pmtcount_693L', 'pmtcount_693L_lag_1']
# ####### NAN count = 1380253
# Use these: ['pmtscount_423L', 'pmtssum_45A', 'pmtscount_423L_lag_1', 'pmtssum_45A_lag_1']
# ####### NAN count = 954021
# Use these: ['responsedate_1012D', 'responsedate_1012D_lag_1']
# ####### NAN count = 806659
# Use these: ['responsedate_4527233D', 'responsedate_4527233D_lag_1']
# ####### NAN count = 866332
# ####### NAN count = 1301747
# ####### NAN count = 418178
# Use these: ['amtinstpaidbefduel24m_4187115A', 'numinstlswithdpd5_4187116L']
# ####### NAN count = 561124
# Use these: ['annuitynextmonth_57A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'numinstls_657L', 'totalsettled_863A']
# ####### NAN count = 4
# Use these: ['mindbddpdlast24m_3658935P']
# ####### NAN count = 613202
# ####### NAN count = 948244
# Use these: ['mindbdtollast24m_4525191P']
# ####### NAN count = 972827
# ####### NAN count = 467175
# Use these: ['avginstallast24m_3658937A', 'maxinstallast24m_3658928A']
# ####### NAN count = 624875
# ####### NAN count = 1364150
# ####### NAN count = 757006
# ####### NAN count = 841181
# ####### NAN count = 1026987
# ####### NAN count = 455190
# ####### NAN count = 460822
# Use these: ['commnoinclast6m_3546845L', 'maxdpdfrom6mto36m_3546853P']
# ####### NAN count = 343375
# ####### NAN count = 833735
# Use these: ['datelastinstal40dpd_247D', 'datelastinstal40dpd_247D_lag_1']
# ####### NAN count = 1392841
# ####### NAN count = 887659
# Use these: ['daysoverduetolerancedd_3976961L', 'numinsttopaygr_769L']
# ####### NAN count = 452594
# ####### NAN count = 977119
# Use these: ['eir_270L']
# ####### NAN count = 190833
# ####### NAN count = 859214
# ####### NAN count = 482103
# Use these: ['inittransactionamount_650A', 'inittransactionamount_650A_lag_1']
# ####### NAN count = 1334357
# ####### NAN count = 453587
# Use these: ['lastapplicationdate_877D', 'min_creationdate_885D', 'max_num_group1']
# ####### NAN count = 305137
# Use these: ['lastapprcredamount_781A', 'lastapprdate_640D']
# ####### NAN count = 442041
# ####### NAN count = 977975
# Use these: ['lastrejectcredamount_222A', 'lastrejectdate_50D']
# ####### NAN count = 769046
# ####### NAN count = 511255
# Use these: ['mastercontrelectronic_519L', 'mastercontrexist_109L', 'maxannuity_159A', 'maxdebt4_972A', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdtolerance_374P']
# ####### NAN count = 306019
# ####### NAN count = 960953
# ####### NAN count = 705504
# ####### NAN count = 876276
# ####### NAN count = 826000
# ####### NAN count = 829402
# ####### NAN count = 1032856
# ####### NAN count = 766958
# ####### NAN count = 1129330
# Use these: ['numinstpaidearly_338L', 'numinstpaidearly5d_1087L', 'numinstpaidlate1d_3546852L']
# ####### NAN count = 452593
# ####### NAN count = 455081
# Use these: ['numinstlsallpaid_934L']
# ####### NAN count = 445669
# Use these: ['numinstlswithdpd10_728L', 'numinstlswithoutdpd_562L']
# ####### NAN count = 456495
# Use these: ['numinstpaid_4499208L']
# ####### NAN count = 847191
# ####### NAN count = 446983
# Use these: ['numinstregularpaidest_4493210L', 'numinstpaidearly5dest_4493211L', 'sumoutstandtotalest_4493215A']
# ####### NAN count = 840646
# ####### NAN count = 669186
# ####### NAN count = 455612
# Use these: ['pctinstlsallpaidearl3d_427L', 'pctinstlsallpaidlate1d_3546856L']
# ####### NAN count = 458738
# ####### NAN count = 461362
# ####### NAN count = 459827
# ####### NAN count = 460079
# ####### NAN count = 44954
# ####### NAN count = 78526
# ####### NAN count = 131888
# ####### NAN count = 181122
# ####### NAN count = 223240
# ####### NAN count = 445320
# Use these: ['totaldebt_9A', 'mobilephncnt_593L_growth_rate']
# ####### NAN count = 3
# ####### NAN count = 1174211
# Use these: ['validfrom_1069D', 'validfrom_1069D_lag_1']
# ####### NAN count = 1374886
# Use these: ['mean_actualdpd_943P', 'min_actualdpd_943P']
# ####### NAN count = 305154
# Use these: ['max_annuity_853A', 'min_annuity_853A', 'mean_annuity_853A']
# ####### NAN count = 308739
# Use these: ['mean_credacc_actualbalance_314A', 'mean_credacc_maxhisbal_375A', 'mean_credacc_minhisbal_90A', 'max_credacc_transactions_402L']
# ####### NAN count = 1273086
# Use these: ['max_credacc_credlmt_575A', 'max_credamount_590A', 'max_downpmt_134A', 'min_credacc_credlmt_575A', 'min_credamount_590A', 'min_downpmt_134A', 'mean_credacc_credlmt_575A', 'mean_credamount_590A', 'mean_downpmt_134A']
# ####### NAN count = 307441
# Use these: ['max_currdebt_94A', 'min_currdebt_94A', 'mean_currdebt_94A']
# ####### NAN count = 419006
# Use these: ['max_mainoccupationinc_437A', 'min_mainoccupationinc_437A', 'mean_mainoccupationinc_437A']
# ####### NAN count = 306361
# Use these: ['mean_maxdpdtolerance_577P', 'min_maxdpdtolerance_577P']
# ####### NAN count = 450969
# Use these: ['max_outstandingdebt_522A', 'min_outstandingdebt_522A', 'mean_outstandingdebt_522A']
# ####### NAN count = 420383
# Use these: ['mean_revolvingaccount_394A']
# ####### NAN count = 1273082
# ####### NAN count = 535095
# ####### NAN count = 543674
# ####### NAN count = 539780
# Use these: ['std_credamount_590A', 'std_downpmt_134A']
# ####### NAN count = 540212
# ####### NAN count = 701318
# ####### NAN count = 538908
# ####### NAN count = 759462
# ####### NAN count = 702928
# Use these: ['min_approvaldate_319D', 'max_approvaldate_319D']
# ####### NAN count = 442999
# Use these: ['min_dateactivated_425D', 'max_dateactivated_425D']
# ####### NAN count = 454678
# Use these: ['min_dtlastpmt_581D', 'max_dtlastpmt_581D']
# ####### NAN count = 703840
# Use these: ['min_dtlastpmtallstes_3545839D', 'max_dtlastpmtallstes_3545839D']
# ####### NAN count = 548987
# Use these: ['max_employedfrom_700D']
# ####### NAN count = 559169
# Use these: ['min_firstnonzeroinstldate_307D', 'max_firstnonzeroinstldate_307D']
# ####### NAN count = 334873
# ####### NAN count = 961606
# ####### NAN count = 552766
# Use these: ['max_pmtnum_8L']
# ####### NAN count = 321446
# Use these: ['max_amount_4527230A', 'min_amount_4527230A', 'min_recorddate_4527225D', 'max_num_group1_3']
# ####### NAN count = 1068725
# ####### NAN count = 1085243
# Use these: ['mean_amount_4917619A', 'min_amount_4917619A', 'min_deductiondate_4917603D', 'max_deductiondate_4917603D', 'max_num_group1_4']
# ####### NAN count = 1375927
# ####### NAN count = 1377449
# Use these: ['max_pmtamount_36A', 'min_pmtamount_36A', 'min_processingdate_168D', 'max_processingdate_168D', 'max_num_group1_5']
# ####### NAN count = 1044394
# ####### NAN count = 1063483
# Use these: ['mean_credlmt_230A', 'min_credlmt_230A']
# ####### NAN count = 1036944
# Use these: ['mean_credlmt_935A', 'min_credlmt_935A']
# ####### NAN count = 603001
# Use these: ['mean_pmts_dpd_1073P', 'min_dpdmax_139P', 'max_dpdmaxdatemonth_89T', 'max_dpdmaxdateyear_596T']
# ####### NAN count = 263166
# Use these: ['max_pmts_dpd_303P', 'min_dpdmax_757P', 'mean_dpdmax_757P', 'max_dpdmaxdatemonth_442T', 'max_dpdmaxdateyear_896T', 'min_pmts_dpd_303P', 'mean_pmts_dpd_303P']
# ####### NAN count = 514070
# Use these: ['mean_instlamount_768A', 'min_instlamount_768A']
# ####### NAN count = 606920
# Use these: ['mean_instlamount_852A', 'min_instlamount_852A']
# ####### NAN count = 1136162
# Use these: ['mean_monthlyinstlamount_332A', 'min_monthlyinstlamount_332A']
# ####### NAN count = 263233
# Use these: ['max_monthlyinstlamount_674A', 'min_monthlyinstlamount_674A', 'mean_monthlyinstlamount_674A']
# ####### NAN count = 517511
# Use these: ['mean_outstandingamount_354A', 'min_outstandingamount_354A']
# ####### NAN count = 545885
# Use these: ['mean_outstandingamount_362A']
# ####### NAN count = 636453
# Use these: ['mean_overdueamount_31A', 'min_overdueamount_31A']
# ####### NAN count = 512650
# Use these: ['mean_overdueamount_659A', 'min_overdueamount_659A', 'max_numberofoverdueinstls_725L']
# ####### NAN count = 263171
# Use these: ['mean_overdueamountmax2_14A', 'mean_totaloutstanddebtvalue_39A', 'min_overdueamountmax2_14A', 'min_totaldebtoverduevalue_178A', 'min_totaloutstanddebtvalue_39A', 'min_dateofcredend_289D', 'min_dateofcredstart_739D', 'min_lastupdate_1112D', 'max_dateofcredend_289D', 'max_dateofcredstart_739D', 'max_lastupdate_1112D', 'max_numberofcontrsvalue_258L', 'max_numberofoverdueinstlmax_1039L', 'max_overdueamountmaxdatemonth_365T', 'max_overdueamountmaxdateyear_2T', 'min_pmts_overdue_1140A', 'mean_pmts_overdue_1140A', 'max_pmts_month_158T', 'max_pmts_year_1139T']
# ####### NAN count = 262653
# Use these: ['mean_overdueamountmax2_398A', 'min_overdueamountmax2_398A', 'min_dateofcredend_353D', 'max_dateofcredend_353D', 'max_dateofcredstart_181D', 'max_numberofoverdueinstlmax_1151L']
# ####### NAN count = 512590
# Use these: ['mean_overdueamountmax_35A', 'min_overdueamountmax_35A', 'max_overdueamountmaxdatemonth_284T', 'max_overdueamountmaxdateyear_994T', 'min_pmts_overdue_1152A', 'mean_pmts_overdue_1152A']
# ####### NAN count = 513987
# Use these: ['max_residualamount_488A']
# ####### NAN count = 1039597
# Use these: ['mean_residualamount_856A', 'min_residualamount_856A']
# ####### NAN count = 606900
# Use these: ['max_totalamount_6A', 'mean_totalamount_6A']
# ####### NAN count = 545855
# Use these: ['mean_totalamount_996A']
# ####### NAN count = 636448
# Use these: ['mean_totaldebtoverduevalue_718A', 'mean_totaloutstanddebtvalue_668A', 'min_totaloutstanddebtvalue_668A', 'max_numberofcontrsvalue_358L']
# ####### NAN count = 297072
# ####### NAN count = 1308268
# ####### NAN count = 1246089
# ####### NAN count = 729184
# ####### NAN count = 654687
# ####### NAN count = 1253365
# ####### NAN count = 1400301
# ####### NAN count = 729342
# ####### NAN count = 661628
# ####### NAN count = 698560
# ####### NAN count = 1160503
# ####### NAN count = 650655
# ####### NAN count = 729205
# ####### NAN count = 727677
# ####### NAN count = 650524
# ####### NAN count = 727678
# ####### NAN count = 654541
# ####### NAN count = 1310473
# ####### NAN count = 1253324
# ####### NAN count = 698532
# ####### NAN count = 1160489
# Use these: ['min_dateofrealrepmt_138D', 'max_dateofrealrepmt_138D']
# ####### NAN count = 512961
# Use these: ['min_lastupdate_388D', 'max_lastupdate_388D']
# ####### NAN count = 512591
# Use these: ['min_numberofoverdueinstlmaxdat_148D', 'max_numberofoverdueinstlmaxdat_148D']
# ####### NAN count = 802351
# Use these: ['min_numberofoverdueinstlmaxdat_641D']
# ####### NAN count = 1012361
# Use these: ['min_overdueamountmax2date_1002D', 'max_overdueamountmax2date_1002D']
# ####### NAN count = 806653
# Use these: ['min_overdueamountmax2date_1142D']
# ####### NAN count = 1007594
# ####### NAN count = 1237917
# ####### NAN count = 1270160
# ####### NAN count = 822517
# ####### NAN count = 745109
# ####### NAN count = 545898
# ####### NAN count = 636545
# ####### NAN count = 545895
# ####### NAN count = 636544
# ####### NAN count = 512657
# ####### NAN count = 561307
# ####### NAN count = 649082
# ####### NAN count = 1436524
# ####### NAN count = 140386
# Use these: ['min_empl_employedfrom_271D']
# ####### NAN count = 959958
# Use these: ['mean_amount_416A', 'min_amount_416A', 'min_openingdate_313D', 'max_num_group1_10']
# ####### NAN count = 1421548
# Use these: ['min_openingdate_857D']
# ####### NAN count = 1421572
# ####### NAN count = 1414887
# ####### NAN count = 274257
# ####### NAN count = 517831
# ####### NAN count = 273700
# ####### NAN count = 517731
# ####### NAN count = 262659
# ####### NAN count = 512884
# Use these: ['max_pmts_month_706T', 'max_pmts_year_507T']
# ####### NAN count = 512598
# Use these: ['max_num_group1_13', 'max_num_group2_13']
# ####### NAN count = 141371
# Use these: ['month_decision_moving_average', 'weekday_decision_moving_average', 'disbursedcredamount_1113A_moving_average', 'credamount_770A_lag_1', 'applicationcnt_361L_moving_average', 'applicationcnt_361L_lag_1', 'applications30d_658L_moving_average', 'applications30d_658L_lag_1', 'applicationscnt_1086L_moving_average', 'applicationscnt_1086L_lag_1', 'applicationscnt_464L_moving_average', 'applicationscnt_464L_lag_1', 'applicationscnt_867L_moving_average', 'applicationscnt_867L_lag_1', 'clientscnt_1022L_moving_average', 'clientscnt_1022L_lag_1', 'clientscnt_100L_moving_average', 'clientscnt_100L_lag_1', 'clientscnt_1071L_moving_average', 'clientscnt_1071L_lag_1', 'clientscnt_1130L_moving_average', 'clientscnt_1130L_lag_1', 'clientscnt_157L_moving_average', 'clientscnt_157L_lag_1', 'clientscnt_257L_moving_average', 'clientscnt_257L_lag_1', 'clientscnt_304L_moving_average', 'clientscnt_304L_lag_1', 'clientscnt_360L_moving_average', 'clientscnt_360L_lag_1', 'clientscnt_493L_moving_average', 'clientscnt_493L_lag_1', 'clientscnt_533L_moving_average', 'clientscnt_533L_lag_1', 'clientscnt_887L_moving_average', 'clientscnt_887L_lag_1', 'clientscnt_946L_moving_average', 'clientscnt_946L_lag_1', 'deferredmnthsnum_166L_moving_average', 'deferredmnthsnum_166L_lag_1', 'disbursedcredamount_1113A_lag_1', 'downpmt_116A_moving_average', 'downpmt_116A_lag_1', 'homephncnt_628L_moving_average', 'homephncnt_628L_lag_1', 'isbidproduct_1095L_moving_average', 'mobilephncnt_593L_moving_average', 'mobilephncnt_593L_lag_1', 'numactivecreds_622L_moving_average', 'numactivecreds_622L_lag_1', 'numactivecredschannel_414L_moving_average', 'numactivecredschannel_414L_lag_1', 'numactiverelcontr_750L_moving_average', 'numactiverelcontr_750L_lag_1', 'numcontrs3months_479L_moving_average', 'numcontrs3months_479L_lag_1', 'numnotactivated_1143L_moving_average', 'numnotactivated_1143L_lag_1', 'numpmtchanneldd_318L_moving_average', 'numpmtchanneldd_318L_lag_1', 'numrejects9m_859L_moving_average', 'numrejects9m_859L_lag_1', 'sellerplacecnt_915L_moving_average', 'sellerplacecnt_915L_lag_1']
# ####### NAN count = 2
# Use these: ['month_decision_growth_rate', 'weekday_decision_growth_rate', 'annuity_780A_growth_rate', 'credamount_770A_growth_rate', 'pmtnum_254L_growth_rate']
# ####### NAN count = 1
# ####### NAN count = 1513170
# ####### NAN count = 412
# Use these: ['assignmentdate_4527235D_moving_average', 'pmtaverage_4527227A_moving_average', 'pmtcount_4527229L_moving_average']
# ####### NAN count = 1517711
# Use these: ['assignmentdate_4527235D_growth_rate', 'pmtaverage_4527227A_growth_rate', 'pmtcount_4527229L_growth_rate', 'responsedate_4527233D_growth_rate']
# ####### NAN count = 28630
# ####### NAN count = 927212
# ####### NAN count = 358
# ####### NAN count = 1416534
# ####### NAN count = 1369332
# ####### NAN count = 59320
# Use these: ['dateofbirth_337D_moving_average', 'days180_256L_moving_average', 'days30_165L_moving_average', 'days360_512L_moving_average', 'firstquarter_103L_moving_average', 'fourthquarter_440L_moving_average', 'secondquarter_766L_moving_average', 'thirdquarter_1082L_moving_average']
# ####### NAN count = 311598
# Use these: ['dateofbirth_337D_lag_1', 'days180_256L_lag_1', 'days30_165L_lag_1', 'days360_512L_lag_1', 'firstquarter_103L_lag_1', 'fourthquarter_440L_lag_1', 'secondquarter_766L_lag_1', 'thirdquarter_1082L_lag_1']
# ####### NAN count = 140970
# ####### NAN count = 389
# ####### NAN count = 257198
# ####### NAN count = 157161
# ####### NAN count = 706202
# Use these: ['days360_512L_growth_rate']
# ####### NAN count = 63053
# ####### NAN count = 351210
# ####### NAN count = 188791
# ####### NAN count = 168473
# ####### NAN count = 1512222
# ####### NAN count = 46765
# ####### NAN count = 1510623
# ####### NAN count = 46622
# Use these: ['pmtscount_423L_moving_average', 'pmtssum_45A_moving_average']
# ####### NAN count = 1145188
# Use these: ['pmtscount_423L_growth_rate', 'pmtssum_45A_growth_rate']
# ####### NAN count = 37885
# ####### NAN count = 822800
# ####### NAN count = 626
# ####### NAN count = 890685
# ####### NAN count = 1311780
# ####### NAN count = 1301749
# ####### NAN count = 49482
# ####### NAN count = 180494
# ####### NAN count = 160974
# ####### NAN count = 489684
# ####### NAN count = 418180
# ####### NAN count = 1518194
# Use these: ['amtinstpaidbefduel24m_4187115A_moving_average', 'numinstlswithdpd5_4187116L_moving_average']
# ####### NAN count = 601162
# Use these: ['amtinstpaidbefduel24m_4187115A_lag_1', 'numinstlswithdpd5_4187116L_lag_1']
# ####### NAN count = 561126
# ####### NAN count = 85722
# Use these: ['annuitynextmonth_57A_moving_average', 'currdebt_22A_moving_average', 'currdebtcredtyperange_828A_moving_average', 'numinstls_657L_moving_average', 'totalsettled_863A_moving_average']
# ####### NAN count = 14
# Use these: ['annuitynextmonth_57A_lag_1', 'currdebt_22A_lag_1', 'currdebtcredtyperange_828A_lag_1', 'numinstls_657L_lag_1', 'totalsettled_863A_lag_1']
# ####### NAN count = 6
# ####### NAN count = 788354
# ####### NAN count = 1526631
# ####### NAN count = 1226664
# ####### NAN count = 1375071
# ####### NAN count = 1286878
# ####### NAN count = 1379790
# ####### NAN count = 249350
# Use these: ['mindbddpdlast24m_3658935P_moving_average']
# ####### NAN count = 889948
# Use these: ['mindbddpdlast24m_3658935P_lag_1']
# ####### NAN count = 613204
# ####### NAN count = 80076
# ####### NAN count = 1322692
# ####### NAN count = 948246
# ####### NAN count = 191126
# Use these: ['mindbdtollast24m_4525191P_moving_average']
# ####### NAN count = 1137533
# Use these: ['mindbdtollast24m_4525191P_lag_1']
# ####### NAN count = 972829
# ####### NAN count = 340976
# ####### NAN count = 526966
# ####### NAN count = 467177
# ####### NAN count = 972680
# Use these: ['avginstallast24m_3658937A_moving_average', 'maxinstallast24m_3658928A_moving_average']
# ####### NAN count = 913281
# Use these: ['avginstallast24m_3658937A_lag_1', 'maxinstallast24m_3658928A_lag_1']
# ####### NAN count = 624877
# Use these: ['avginstallast24m_3658937A_growth_rate', 'maxinstallast24m_3658928A_growth_rate']
# ####### NAN count = 15
# ####### NAN count = 1517937
# ####### NAN count = 1364151
# ####### NAN count = 27664
# ####### NAN count = 1142962
# ####### NAN count = 757008
# ####### NAN count = 1134540
# ####### NAN count = 1199227
# ####### NAN count = 841183
# ####### NAN count = 39757
# ####### NAN count = 1239991
# ####### NAN count = 1026989
# ####### NAN count = 28195
# ####### NAN count = 1440690
# ####### NAN count = 1489590
# ####### NAN count = 1470941
# ####### NAN count = 1398118
# ####### NAN count = 1270792
# ####### NAN count = 1429999
# ####### NAN count = 1443721
# ####### NAN count = 1390534
# ####### NAN count = 1517891
# ####### NAN count = 1411562
# ####### NAN count = 1517694
# ####### NAN count = 1507717
# ####### NAN count = 1325708
# ####### NAN count = 1240774
# ####### NAN count = 1440715
# ####### NAN count = 499138
# ####### NAN count = 455192
# ####### NAN count = 117874
# ####### NAN count = 512889
# ####### NAN count = 460824
# ####### NAN count = 24932
# Use these: ['commnoinclast6m_3546845L_moving_average', 'maxdpdfrom6mto36m_3546853P_moving_average']
# ####### NAN count = 470006
# Use these: ['commnoinclast6m_3546845L_lag_1', 'maxdpdfrom6mto36m_3546853P_lag_1']
# ####### NAN count = 343377
# Use these: ['commnoinclast6m_3546845L_growth_rate', 'deferredmnthsnum_166L_growth_rate', 'mastercontrelectronic_519L_growth_rate', 'mastercontrexist_109L_growth_rate']
# ####### NAN count = 1526659
# ####### NAN count = 741030
# ####### NAN count = 986109
# ####### NAN count = 1207745
# ####### NAN count = 833736
# ####### NAN count = 229
# ####### NAN count = 1523007
# ####### NAN count = 69980
# ####### NAN count = 1286238
# ####### NAN count = 887661
# ####### NAN count = 9897
# Use these: ['daysoverduetolerancedd_3976961L_moving_average', 'numinsttopaygr_769L_moving_average']
# ####### NAN count = 497997
# Use these: ['daysoverduetolerancedd_3976961L_lag_1', 'numinsttopaygr_769L_lag_1']
# ####### NAN count = 452596
# ####### NAN count = 498978
# ####### NAN count = 5385
# ####### NAN count = 1352516
# ####### NAN count = 1177618
# ####### NAN count = 977120
# ####### NAN count = 35886
# Use these: ['eir_270L_moving_average']
# ####### NAN count = 492007
# Use these: ['eir_270L_lag_1']
# ####### NAN count = 190835
# Use these: ['eir_270L_growth_rate']
# ####### NAN count = 276186
# ####### NAN count = 1197635
# ####### NAN count = 859215
# ####### NAN count = 272
# ####### NAN count = 568984
# ####### NAN count = 482105
# ####### NAN count = 3167
# ####### NAN count = 531983
# ####### NAN count = 1521340
# ####### NAN count = 384229
# ####### NAN count = 1338359
# ####### NAN count = 499075
# ####### NAN count = 453589
# ####### NAN count = 2550
# ####### NAN count = 457863
# ####### NAN count = 305139
# ####### NAN count = 788
# Use these: ['lastapprcredamount_781A_moving_average', 'lastapprdate_640D_moving_average']
# ####### NAN count = 485776
# Use these: ['lastapprcredamount_781A_lag_1', 'lastapprdate_640D_lag_1']
# ####### NAN count = 442043
# ####### NAN count = 40495
# ####### NAN count = 631
# ####### NAN count = 1371052
# ####### NAN count = 977977
# ####### NAN count = 9270
# Use these: ['lastrejectcredamount_222A_moving_average', 'lastrejectdate_50D_moving_average']
# ####### NAN count = 1279313
# Use these: ['lastrejectcredamount_222A_lag_1', 'lastrejectdate_50D_lag_1']
# ####### NAN count = 769047
# ####### NAN count = 36737
# ####### NAN count = 1611
# ####### NAN count = 653139
# ####### NAN count = 511256
# ####### NAN count = 67
# Use these: ['mastercontrelectronic_519L_moving_average', 'mastercontrexist_109L_moving_average', 'maxannuity_159A_moving_average', 'maxdebt4_972A_moving_average', 'maxdpdlast24m_143P_moving_average', 'maxdpdlast3m_392P_moving_average', 'maxdpdtolerance_374P_moving_average']
# ####### NAN count = 457443
# Use these: ['mastercontrelectronic_519L_lag_1', 'mastercontrexist_109L_lag_1', 'maxannuity_159A_lag_1', 'maxdebt4_972A_lag_1', 'maxdpdlast24m_143P_lag_1', 'maxdpdlast3m_392P_lag_1', 'maxdpdtolerance_374P_lag_1']
# ####### NAN count = 306021
# ####### NAN count = 360985
# ####### NAN count = 1369209
# ####### NAN count = 960955
# ####### NAN count = 214973
# ####### NAN count = 1062848
# ####### NAN count = 705506
# ####### NAN count = 305306
# ####### NAN count = 1239165
# ####### NAN count = 876278
# ####### NAN count = 441238
# ####### NAN count = 482283
# ####### NAN count = 882058
# ####### NAN count = 1211118
# ####### NAN count = 826002
# ####### NAN count = 6942
# ####### NAN count = 1215643
# ####### NAN count = 829404
# ####### NAN count = 21904
# ####### NAN count = 1001828
# ####### NAN count = 863175
# ####### NAN count = 1244526
# ####### NAN count = 1132113
# ####### NAN count = 1057613
# ####### NAN count = 638003
# ####### NAN count = 1251979
# ####### NAN count = 1032858
# ####### NAN count = 28573
# ####### NAN count = 1081592
# ####### NAN count = 766960
# ####### NAN count = 37504
# ####### NAN count = 1380656
# ####### NAN count = 1129332
# ####### NAN count = 28657
# ####### NAN count = 61684
# ####### NAN count = 331848
# Use these: ['numinstpaidearly_338L_moving_average', 'numinstpaidearly5d_1087L_moving_average', 'numinstpaidlate1d_3546852L_moving_average']
# ####### NAN count = 497994
# Use these: ['numinstpaidearly_338L_lag_1', 'numinstpaidearly5d_1087L_lag_1', 'numinstpaidlate1d_3546852L_lag_1']
# ####### NAN count = 452595
# ####### NAN count = 108620
# ####### NAN count = 693410
# ####### NAN count = 1256614
# ####### NAN count = 924634
# ####### NAN count = 1034138
# ####### NAN count = 498856
# ####### NAN count = 455083
# ####### NAN count = 7175
# Use these: ['numinstlsallpaid_934L_moving_average']
# ####### NAN count = 486751
# Use these: ['numinstlsallpaid_934L_lag_1']
# ####### NAN count = 445671
# ####### NAN count = 188137
# ####### NAN count = 765354
# ####### NAN count = 103682
# Use these: ['numinstlswithdpd10_728L_moving_average', 'numinstlswithoutdpd_562L_moving_average']
# ####### NAN count = 498341
# Use these: ['numinstlswithdpd10_728L_lag_1', 'numinstlswithoutdpd_562L_lag_1']
# ####### NAN count = 456497
# ####### NAN count = 1009068
# ####### NAN count = 924300
# ####### NAN count = 11587
# Use these: ['numinstpaid_4499208L_moving_average']
# ####### NAN count = 874767
# Use these: ['numinstpaid_4499208L_lag_1']
# ####### NAN count = 847193
# ####### NAN count = 374081
# ####### NAN count = 55699
# ####### NAN count = 490668
# ####### NAN count = 446985
# ####### NAN count = 191077
# Use these: ['numinstregularpaidest_4493210L_moving_average', 'numinstpaidearly5dest_4493211L_moving_average', 'sumoutstandtotalest_4493215A_moving_average']
# ####### NAN count = 868490
# Use these: ['numinstregularpaidest_4493210L_lag_1', 'numinstpaidearly5dest_4493211L_lag_1', 'sumoutstandtotalest_4493215A_lag_1']
# ####### NAN count = 840648
# ####### NAN count = 424551
# ####### NAN count = 351978
# ####### NAN count = 557315
# ####### NAN count = 474338
# ####### NAN count = 245866
# ####### NAN count = 472564
# ####### NAN count = 704713
# ####### NAN count = 669188
# ####### NAN count = 67214
# ####### NAN count = 540638
# ####### NAN count = 500986
# ####### NAN count = 455614
# ####### NAN count = 41781
# ####### NAN count = 55720
# ####### NAN count = 469457
# ####### NAN count = 453398
# ####### NAN count = 468837
# ####### NAN count = 451931
# ####### NAN count = 1466204
# ####### NAN count = 1456897
# ####### NAN count = 1034487
# Use these: ['pctinstlsallpaidearl3d_427L_moving_average', 'pctinstlsallpaidlate1d_3546856L_moving_average']
# ####### NAN count = 502199
# Use these: ['pctinstlsallpaidearl3d_427L_lag_1', 'pctinstlsallpaidlate1d_3546856L_lag_1']
# ####### NAN count = 458740
# ####### NAN count = 143299
# ####### NAN count = 502358
# ####### NAN count = 461364
# ####### NAN count = 798372
# ####### NAN count = 525388
# ####### NAN count = 502262
# ####### NAN count = 459829
# ####### NAN count = 689457
# ####### NAN count = 502277
# ####### NAN count = 460081
# ####### NAN count = 740043
# ####### NAN count = 119242
# ####### NAN count = 44956
# ####### NAN count = 157912
# ####### NAN count = 78528
# ####### NAN count = 1479358
# ####### NAN count = 303597
# ####### NAN count = 131890
# ####### NAN count = 1503420
# ####### NAN count = 424758
# ####### NAN count = 181124
# ####### NAN count = 1440778
# ####### NAN count = 346805
# ####### NAN count = 223241
# ####### NAN count = 374613
# ####### NAN count = 1145784
# ####### NAN count = 311780
# ####### NAN count = 489747
# ####### NAN count = 445322
# ####### NAN count = 448162
# ####### NAN count = 416946
# ####### NAN count = 11
# ####### NAN count = 5
# ####### NAN count = 741004
# ####### NAN count = 417251
# ####### NAN count = 1423157
# ####### NAN count = 1174213
# ####### NAN count = 27594
# ####### NAN count = 1385024
# ####### NAN count = 4384
# Selected numerical columns: ['case_id', 'WEEK_NUM', 'target', 'month_decision', 'weekday_decision', 'credamount_770A', 'applicationcnt_361L', 'applications30d_658L', 'applicationscnt_1086L', 'applicationscnt_464L', 'applicationscnt_867L', 'clientscnt_1022L', 'clientscnt_100L', 'clientscnt_1071L', 'clientscnt_1130L', 'clientscnt_157L', 'clientscnt_257L', 'clientscnt_304L', 'clientscnt_360L', 'clientscnt_493L', 'clientscnt_533L', 'clientscnt_887L', 'clientscnt_946L', 'deferredmnthsnum_166L', 'disbursedcredamount_1113A', 'downpmt_116A', 'homephncnt_628L', 'isbidproduct_1095L', 'mobilephncnt_593L', 'numactivecreds_622L', 'numactivecredschannel_414L', 'numactiverelcontr_750L', 'numcontrs3months_479L', 'numnotactivated_1143L', 'numpmtchanneldd_318L', 'numrejects9m_859L', 'sellerplacecnt_915L', 'max_mainoccupationinc_384A', 'min_birth_259D', 'max_num_group1_9', 'assignmentdate_238D', 'assignmentdate_238D_lag_1', 'assignmentdate_4527235D', 'pmtaverage_4527227A', 'pmtcount_4527229L', 'assignmentdate_4527235D_lag_1', 'pmtaverage_4527227A_lag_1', 'birthdate_574D', 'birthdate_574D_lag_1', 'contractssum_5085716L', 'dateofbirth_337D', 'days180_256L', 'days30_165L', 'days360_512L', 'firstquarter_103L', 'fourthquarter_440L', 'secondquarter_766L', 'thirdquarter_1082L', 'max_debtoutstand_525A', 'max_debtoverdue_47A', 'min_refreshdate_3813885D', 'max_refreshdate_3813885D', 'pmtaverage_3A', 'pmtaverage_3A_lag_1', 'pmtcount_693L', 'pmtcount_693L_lag_1', 'pmtscount_423L', 'pmtssum_45A', 'pmtscount_423L_lag_1', 'pmtssum_45A_lag_1', 'responsedate_1012D', 'responsedate_1012D_lag_1', 'responsedate_4527233D', 'responsedate_4527233D_lag_1', 'responsedate_4917613D', 'actualdpdtolerance_344P', 'amtinstpaidbefduel24m_4187115A', 'numinstlswithdpd5_4187116L', 'annuitynextmonth_57A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'numinstls_657L', 'totalsettled_863A', 'mindbddpdlast24m_3658935P', 'avgdbddpdlast3m_4187120P', 'mindbdtollast24m_4525191P', 'avgdpdtolclosure24_3658938P', 'avginstallast24m_3658937A', 'maxinstallast24m_3658928A', 'avglnamtstart24m_4525187A', 'avgmaxdpdlast9m_3716943P', 'avgoutstandbalancel6m_4187114A', 'avgpmtlast12m_4525200A', 'cntincpaycont9m_3716944L', 'cntpmts24_3658933L', 'commnoinclast6m_3546845L', 'maxdpdfrom6mto36m_3546853P', 'datefirstoffer_1144D', 'datelastinstal40dpd_247D', 'datelastinstal40dpd_247D_lag_1', 'datelastunpaid_3546854D', 'daysoverduetolerancedd_3976961L', 'numinsttopaygr_769L', 'dtlastpmtallstes_4499206D', 'eir_270L', 'firstclxcampaign_1125D', 'firstdatedue_489D', 'inittransactionamount_650A', 'inittransactionamount_650A_lag_1', 'lastactivateddate_801D', 'lastapplicationdate_877D', 'min_creationdate_885D', 'max_num_group1', 'lastapprcredamount_781A', 'lastapprdate_640D', 'lastdelinqdate_224D', 'lastrejectcredamount_222A', 'lastrejectdate_50D', 'maininc_215A', 'mastercontrelectronic_519L', 'mastercontrexist_109L', 'maxannuity_159A', 'maxdebt4_972A', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdtolerance_374P', 'maxdbddpdlast1m_3658939P', 'maxdbddpdtollast12m_3658940P', 'maxdbddpdtollast6m_4187119P', 'maxdpdinstldate_3546855D', 'maxdpdinstlnum_3546846P', 'maxlnamtstart6m_4525199A', 'maxoutstandbalancel12m_4187113A', 'maxpmtlast3m_4525190A', 'numinstpaidearly_338L', 'numinstpaidearly5d_1087L', 'numinstpaidlate1d_3546852L', 'numincomingpmts_3546848L', 'numinstlsallpaid_934L', 'numinstlswithdpd10_728L', 'numinstlswithoutdpd_562L', 'numinstpaid_4499208L', 'numinstpaidearly3d_3546850L', 'numinstregularpaidest_4493210L', 'numinstpaidearly5dest_4493211L', 'sumoutstandtotalest_4493215A', 'numinstpaidlastcontr_4325080L', 'numinstregularpaid_973L', 'pctinstlsallpaidearl3d_427L', 'pctinstlsallpaidlate1d_3546856L', 'pctinstlsallpaidlat10d_839L', 'pctinstlsallpaidlate4d_3546849L', 'pctinstlsallpaidlate6d_3546844L', 'pmtnum_254L', 'posfpd10lastmonth_333P', 'posfpd30lastmonth_3976960P', 'posfstqpd30lastmonth_3976962P', 'price_1097A', 'sumoutstandtotal_3546847A', 'totaldebt_9A', 'mobilephncnt_593L_growth_rate', 'totinstalla ...
# Total columns used: 856
# train data shape:	 (1526659, 1005)

# %%
df_test = feature_eng(**test_data_store)
print("test data shape:\t", df_test.shape)
del test_data_store
gc.collect()

df_test, cat_cols = to_pandas(df_test, cat_cols)
df_test = feature_engg(df_test)
features = [col for col in df_train.columns if col != CFG.target_col and col not in ["case_id", "WEEK_NUM"]]
df_test = reduce_mem_usage(df_test[features])
print("test data shape:\t", df_test.shape)
# Out:
# test data shape:	 (10, 737)
# Memory usage of dataframe is 0.08 MB
# Memory usage after optimization is: 0.06 MB
# Decreased by 25.8%
# test data shape:	 (10, 1002)

# %%
for col in df_train.select_dtypes('category').columns:
    df_train[col] = df_train[col].cat.add_categories(['Unknown']).fillna('Unknown')
    df_test[col] = df_test[col].cat.add_categories(['Unknown']).fillna('Unknown')
    
features = [col for col in df_train.columns if col != CFG.target_col and col not in ["case_id", "WEEK_NUM"]]

# %%
Learning(df_train, features)
# Out:
# --------------------------------------------------
# lightgbm training fold 1
# [LightGBM] [Info] Number of positive: 36635, number of negative: 1134229
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 6.841212 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160791
# [LightGBM] [Info] Number of data points in the train set: 1170864, number of used features: 994
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031289 -> initscore=-3.432704
# [LightGBM] [Info] Start training from score -3.432704
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [434]	training's auc: 0.897508	valid_1's auc: 0.858056
#                               feature  importance
# 45        avgdpdtolclosure24_3658938P    0.070576
# 494               mean_pmts_dpd_1073P    0.037114
# 495                mean_pmts_dpd_303P    0.029933
# 496           mean_pmts_overdue_1140A    0.028786
# 223         mean_maxdpdtolerance_577P    0.026885
# ..                                ...         ...
# 753  interestrate_311L_moving_average    0.000000
# 748             homephncnt_628L_lag_1    0.000000
# 177               sellerplacecnt_915L    0.000000
# 184                twobodfilling_608L    0.000000
# 471                 max_remitter_829L    0.000000
#
# [1002 rows x 2 columns]
# --------------------------------------------------
# lightgbm training fold 2
# [LightGBM] [Info] Number of positive: 38784, number of negative: 1190698
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 7.066281 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160806
# [LightGBM] [Info] Number of data points in the train set: 1229482, number of used features: 993
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031545 -> initscore=-3.424287
# [LightGBM] [Info] Start training from score -3.424287
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.900915	valid_1's auc: 0.852409
#                                  feature  importance
# 45           avgdpdtolclosure24_3658938P    0.071036
# 496              mean_pmts_overdue_1140A    0.034139
# 494                  mean_pmts_dpd_1073P    0.030672
# 495                   mean_pmts_dpd_303P    0.030003
# 223            mean_maxdpdtolerance_577P    0.027450
# ..                                   ...         ...
# 560     numberofqueries_373L_growth_rate    0.000000
# 559           numberofqueries_373L_lag_1    0.000000
# 558  numberofqueries_373L_moving_average    0.000000
# 518           month_decision_growth_rate    0.000000
# 343                 mean_debtoverdue_47A    0.000000
#
# [1002 rows x 2 columns]
# --------------------------------------------------
# lightgbm training fold 3
# [LightGBM] [Info] Number of positive: 39477, number of negative: 1197295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 4.392549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160651
# [LightGBM] [Info] Number of data points in the train set: 1236772, number of used features: 992
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031919 -> initscore=-3.412102
# [LightGBM] [Info] Start training from score -3.412102
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [492]	training's auc: 0.899964	valid_1's auc: 0.856217
#                               feature  importance
# 45        avgdpdtolclosure24_3658938P    0.072283
# 496           mean_pmts_overdue_1140A    0.035439
# 495                mean_pmts_dpd_303P    0.031642
# 494               mean_pmts_dpd_1073P    0.029190
# 223         mean_maxdpdtolerance_577P    0.023156
# ..                                ...         ...
# 456        max_empladdr_district_926M    0.000000
# 457         max_empladdr_zipcode_114M    0.000000
# 166                      paytype_783L    0.000000
# 459      max_contaddr_matchlist_1032L    0.000000
# 753  interestrate_311L_moving_average    0.000000
#
# [1002 rows x 2 columns]
# --------------------------------------------------
# lightgbm training fold 4
# [LightGBM] [Info] Number of positive: 39478, number of negative: 1213340
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 9.941412 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160843
# [LightGBM] [Info] Number of data points in the train set: 1252818, number of used features: 994
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031511 -> initscore=-3.425389
# [LightGBM] [Info] Start training from score -3.425389
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [446]	training's auc: 0.895198	valid_1's auc: 0.85391
#                                      feature  importance
# 45               avgdpdtolclosure24_3658938P    0.078621
# 495                       mean_pmts_dpd_303P    0.035325
# 494                      mean_pmts_dpd_1073P    0.034382
# 496                  mean_pmts_overdue_1140A    0.032881
# 176                              price_1097A    0.022445
# ..                                       ...         ...
# 702  commnoinclast6m_3546845L_moving_average    0.000000
# 203                 min_credacc_credlmt_575A    0.000000
# 693           clientscnt_946L_moving_average    0.000000
# 363          mean_totaldebtoverduevalue_718A    0.000000
# 704     commnoinclast6m_3546845L_growth_rate    0.000000
#
# [1002 rows x 2 columns]
# --------------------------------------------------
# lightgbm training fold 5
# [LightGBM] [Info] Number of positive: 37602, number of negative: 1179098
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 4.302067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160716
# [LightGBM] [Info] Number of data points in the train set: 1216700, number of used features: 992
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.030905 -> initscore=-3.445448
# [LightGBM] [Info] Start training from score -3.445448
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [494]	training's auc: 0.901598	valid_1's auc: 0.852959
#                                      feature  importance
# 45               avgdpdtolclosure24_3658938P    0.078386
# 496                  mean_pmts_overdue_1140A    0.034022
# 495                       mean_pmts_dpd_303P    0.031039
# 494                      mean_pmts_dpd_1073P    0.028246
# 176                              price_1097A    0.023024
# ..                                       ...         ...
# 525   assignmentdate_4527235D_moving_average    0.000000
# 243                    max_creationdate_885D    0.000000
# 702  commnoinclast6m_3546845L_moving_average    0.000000
# 703           commnoinclast6m_3546845L_lag_1    0.000000
# 135                   numactiverelcontr_750L    0.000000
#
# [1002 rows x 2 columns]
# lightgbm our out of folds CV f1score is 0.854864487564022
# --------------------------------------------------
# catboost training fold 1
# 0:	learn: 0.6137391	test: 0.6138647	best: 0.6138647 (0)	total: 2.17s	remaining: 18m 2s
# 25:	learn: 0.1441802	test: 0.1456703	best: 0.1456703 (25)	total: 47.2s	remaining: 14m 21s
# 50:	learn: 0.1240658	test: 0.1257666	best: 0.1257666 (50)	total: 1m 31s	remaining: 13m 24s
# 75:	learn: 0.1201139	test: 0.1217903	best: 0.1217903 (75)	total: 2m 16s	remaining: 12m 41s
# 100:	learn: 0.1180353	test: 0.1197107	best: 0.1197107 (100)	total: 3m 1s	remaining: 11m 55s
# 125:	learn: 0.1166613	test: 0.1183668	best: 0.1183668 (125)	total: 3m 46s	remaining: 11m 13s
# 150:	learn: 0.1156228	test: 0.1173814	best: 0.1173814 (150)	total: 4m 30s	remaining: 10m 26s
# 175:	learn: 0.1148122	test: 0.1165994	best: 0.1165994 (175)	total: 5m 13s	remaining: 9m 37s
# 200:	learn: 0.1142149	test: 0.1160997	best: 0.1160997 (200)	total: 5m 56s	remaining: 8m 49s
# 225:	learn: 0.1136792	test: 0.1155916	best: 0.1155916 (225)	total: 6m 38s	remaining: 8m 3s
# 250:	learn: 0.1131887	test: 0.1151862	best: 0.1151862 (250)	total: 7m 21s	remaining: 7m 18s
# 275:	learn: 0.1127838	test: 0.1148660	best: 0.1148660 (275)	total: 8m 3s	remaining: 6m 32s
# 300:	learn: 0.1123977	test: 0.1145669	best: 0.1145669 (300)	total: 8m 47s	remaining: 5m 48s
# 325:	learn: 0.1120530	test: 0.1143177	best: 0.1143177 (325)	total: 9m 31s	remaining: 5m 5s
# 350:	learn: 0.1117117	test: 0.1140874	best: 0.1140874 (350)	total: 10m 14s	remaining: 4m 20s
# 375:	learn: 0.1113948	test: 0.1138703	best: 0.1138703 (375)	total: 10m 56s	remaining: 3m 36s
# 400:	learn: 0.1111430	test: 0.1137395	best: 0.1137395 (400)	total: 11m 39s	remaining: 2m 52s
# 425:	learn: 0.1108858	test: 0.1135968	best: 0.1135968 (425)	total: 12m 21s	remaining: 2m 8s
# 450:	learn: 0.1106083	test: 0.1134209	best: 0.1134209 (450)	total: 13m 4s	remaining: 1m 25s
# 475:	learn: 0.1103888	test: 0.1132922	best: 0.1132922 (475)	total: 13m 46s	remaining: 41.7s
# 499:	learn: 0.1101876	test: 0.1131811	best: 0.1131811 (499)	total: 14m 28s	remaining: 0us
#
# bestTest = 0.1131811435
# bestIteration = 499
#
# --------------------------------------------------
# catboost training fold 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5326/3629602656.py in ?()
# ----> 1 Learning(df_train, features)
#
# /tmp/ipykernel_5326/3430108955.py in ?(input_df, features)
#      38 def Learning(input_df: pd.DataFrame, features: list):
#      39     for method in CFG.METHOD_LIST:
# ---> 40         gradient_boosting_model_cv_training(method, input_df, features)
#
# /tmp/ipykernel_5326/3430108955.py in ?(method, train_df, features)
#      19             model, valid_pred = lightgbm_training(x_train, y_train, x_valid, y_valid, features)
#      20         if method == 'xgboost':
#      21             model, valid_pred = xgboost_training(x_train, y_train, x_valid, y_valid, features)
#      22         if method == 'catboost':
# ---> 23             model, valid_pred = catboost_training(x_train, y_train, x_valid, y_valid, features)
#      24
#      25         pickle.dump(model, open(CFG.MODEL_DATA_PATH / f'{method}_fold{fold + 1}_seed{CFG.seed}_ver{CFG.VER}.pkl', 'wb'))
#      26
#
# /tmp/ipykernel_5326/3311249204.py in ?(x_train, y_train, x_valid, y_valid, features)
#      39 def catboost_training(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, features: list):
#      40     cat_features = x_train.select_dtypes('category').columns.tolist()
# ---> 41     cat_train = Pool(data=x_train, label=y_train,cat_features=cat_features)
#      42     cat_valid = Pool(data=x_valid, label=y_valid,cat_features=cat_features)
#      43     model = CatBoostClassifier(**CFG.classification_cat_params)
#      44     model.fit(cat_train,
#
# ~/kaggle_HomeCredit/.venv/lib/python3.11/site-packages/catboost/core.py in ?(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr, data_can_be_none)
#     840                             "feature_names must be None or have non-string type when the pool is created from "
#     841                             "python objects."
#     842                         )
#     843
# --> 844                     self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     845                                group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     846             elif not data_can_be_none:
#     847                 raise CatBoostError("'data' parameter can't be None")
#
# ~/kaggle_HomeCredit/.venv/lib/python3.11/site-packages/catboost/core.py in ?(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1473             timestamp = self._if_pandas_to_numpy(timestamp)
#    1474             self._check_timestamp_shape(timestamp, samples_count)
#    1475         if feature_tags is not None:
#    1476             feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1477         self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1478                         group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# _catboost.pyx in ?()
# -> 4159 'Could not get source, probably due dynamically evaluated source code.'
#
# _catboost.pyx in ?()
# -> 4209 'Could not get source, probably due dynamically evaluated source code.'
#
# _catboost.pyx in ?()
# -> 4025 'Could not get source, probably due dynamically evaluated source code.'
#
# _catboost.pyx in ?()
# -> 2905 'Could not get source, probably due dynamically evaluated source code.'
#
# ~/kaggle_HomeCredit/.venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self)
#    1319     @Appender(_shared_docs["items"])
#    1320     def items(self) -> Iterable[tuple[Hashable, Series]]:
#    1321         if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1322             for k in self.columns:
# -> 1323                 yield k, self._get_item_cache(k)
#    1324         else:
#    1325             for i, k in enumerate(self.columns):
#    1326                 yield k, self._ixs(i, axis=1)
#
# KeyboardInterrupt:

# %%
def create_submission(test_df, submission_dir, submission_file):
    df_subm = pd.read_csv(submission_dir)
    df_subm.set_index("case_id", inplace=True)
    
    df_subm["score"] = test_df.set_index("case_id")["pred_prob"]
    df_subm.to_csv(submission_file)

test_df = Predicting(df_test, features)
create_submission(test_df, SAMPLE_SUB, "submission.csv")
