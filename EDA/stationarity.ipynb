# %%
# 標準ライブラリ
import gc
import os
import pickle
import random
import sys
import warnings
from itertools import combinations, permutations
from pathlib import Path
import pytz

# サードパーティのライブラリ
import category_encoders as ce
import joblib
import lightgbm as lgb
import numpy as np
import fireducks.pandas as pd
import polars as pl
import scipy as sp
import seaborn as sns
import torch
import xgboost as xgb
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from dateutil.relativedelta import relativedelta
from sklearn.base import BaseEstimator, ClassifierMixin, RegressorMixin
from sklearn.impute import KNNImputer
from sklearn.metrics import f1_score, log_loss, matthews_corrcoef, roc_auc_score
from sklearn.model_selection import (GroupKFold, KFold, StratifiedKFold,
                                     StratifiedGroupKFold, TimeSeriesSplit,
                                     train_test_split)
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from tqdm.auto import tqdm

import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

import glob
import datetime

# %%
class CFG:
    home_directory = os.path.expanduser('~/kaggle_HomeCredit/')
    kaggle_directory = os.path.expanduser('/kaggle/input/home-credit-credit-risk-model-stability/')
    
    train_data_path = os.path.join(home_directory, 'train/')
    test_data_path = os.path.join(home_directory, 'test/')
    
    OOF_DATA_PATH = Path(home_directory) / 'oof'
    MODEL_DATA_PATH = Path(home_directory) / 'models'
    SUB_DATA_PATH = Path(home_directory) / 'submission'

    def __init__(self):
        self.create_directories()
    
    def create_directories(self):
        for path in [self.OOF_DATA_PATH, self.MODEL_DATA_PATH, self.SUB_DATA_PATH]:
            path.mkdir(parents=True, exist_ok=True)
    
    
    VER = 'time-series_plot'
    AUTHOR = 'Mira'
    COMPETITION = 'HomeCredit'

    METHOD_LIST = ['lightgbm','catboost']
    seed = 28
    n_folds = 5
    target_col = 'target'
    metric = 'auc'
    
    metric_maximize_flag = True
    num_boost_round = 500
    early_stopping_round = 200
    verbose = 25
    classification_lgb_params = {
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': 0.05,
        'seed': seed,
        #"device_type": "gpu",
    }
    classification_xgb_params = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': 0.05,
        'random_state': seed,
        "tree_method": "gpu_hist",
    }

    classification_cat_params = {
        'learning_rate': 0.05,
        'iterations': num_boost_round,
        'random_seed': seed,
        #"task_type": "GPU",
    }
    model_weight_dict = {'lightgbm': 0.5,'catboost':0.5}
    

class is_kaggle:
    def __init__(self, Kaggle):
        if Kaggle == "Yes":
            self.path = Path(CFG.kaggle_directory)
            CFG.MODEL_DATA_PATH = Path('/kaggle/input/04191103/models')
        else:
            self.path = Path(CFG.home_directory)
            CFG.MODEL_DATA_PATH = Path(CFG.home_directory) / 'models'

def create_timestamped_file():
    tz_tokyo = pytz.timezone('Asia/Tokyo')
    now = datetime.datetime.now(tz=tz_tokyo)
    filename = now.strftime('%m%d-%H%M') + '.txt'
    full_path = CFG.MODEL_DATA_PATH / filename
    full_path.touch()

#create_timestamped_file()
cfg_instance = CFG()      
selector = is_kaggle("No")

# %%
class Pipeline:
    @staticmethod
    def set_table_dtypes(df):
        for col in df.columns:
            if col in ["case_id", "WEEK_NUM", "num_group1", "num_group2"]:
                df = df.with_columns(pl.col(col).cast(pl.Int32))
            elif col in ["date_decision"]:
                df = df.with_columns(pl.col(col).cast(pl.Date))
            elif col[-1] in ("P", "A"):
                df = df.with_columns(pl.col(col).cast(pl.Float64))
            elif col[-1] in ("M",):
                df = df.with_columns(pl.col(col).cast(pl.String))
            elif col[-1] in ("D",):
                df = df.with_columns(pl.col(col).cast(pl.Date))            

        return df
    
    @staticmethod
    def handle_dates(df):
        for col in df.columns:
            if col[-1] in ("D",):
                df = df.with_columns(pl.col(col) - pl.col("date_decision"))
                df = df.with_columns(pl.col(col).dt.total_days())
                df = df.with_columns(pl.col(col).cast(pl.Float32))
                
        df = df.drop("date_decision", "MONTH")

        return df
    
    @staticmethod
    def filter_cols(df):
        for col in df.columns:
            if col not in ["target", "case_id", "WEEK_NUM"]:
                isnull = df[col].is_null().mean()

                if isnull > 0.95:
                    df = df.drop(col)

        for col in df.columns:
            if (col not in ["target", "case_id", "WEEK_NUM"]) & (df[col].dtype == pl.String):
                freq = df[col].n_unique()

                if (freq == 1) | (freq > 200):
                    df = df.drop(col)

        return df

# %%
class Aggregator:
    @staticmethod
    def num_expr(df):
        cols = [col for col in df.columns if col[-1] in ("P", "A")]

        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]
        expr_min = [pl.min(col).alias(f"min_{col}") for col in cols]
        expr_mean = [pl.mean(col).alias(f"mean_{col}") for col in cols]
        expr_std = [pl.std(col).alias(f"std_{col}") for col in cols] 

        return expr_max + expr_min + expr_mean + expr_std 

    @staticmethod
    def date_expr(df):
        cols = [col for col in df.columns if col[-1] in ("D",)]

        expr_min = [pl.min(col).alias(f"min_{col}") for col in cols]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_min + expr_max

    @staticmethod
    def str_expr(df):
        cols = [col for col in df.columns if col[-1] in ("M",)]
        
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max

    @staticmethod
    def other_expr(df):
        cols = [col for col in df.columns if col[-1] in ("T", "L")]
        
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max
    
    @staticmethod
    def count_expr(df):
        cols = [col for col in df.columns if "num_group" in col]

        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        return expr_max

    @staticmethod
    def get_exprs(df):
        exprs = Aggregator.num_expr(df) + \
                Aggregator.date_expr(df) + \
                Aggregator.str_expr(df) + \
                Aggregator.other_expr(df) + \
                Aggregator.count_expr(df)

        return exprs

# %%
def read_file(path, depth=None):
    df = pl.read_parquet(path)
    df = df.pipe(Pipeline.set_table_dtypes)
    
    if depth in [1, 2]:
        df = df.group_by("case_id").agg(Aggregator.get_exprs(df))
    
    return df

def read_files(regex_path, depth=None):
    chunks = []
    for path in glob.glob(str(regex_path)):
        df = pl.read_parquet(path)
        df = df.pipe(Pipeline.set_table_dtypes)
        
        if depth in [1, 2]:
            df = df.group_by("case_id").agg(Aggregator.get_exprs(df))
        
        chunks.append(df)
        
    df = pl.concat(chunks, how="vertical_relaxed")
    df = df.unique(subset=["case_id"])
    
    return df

# %%
def feature_eng(df_base, depth_0, depth_1, depth_2):
    df_base = (
        df_base
        .with_columns(
            month_decision = pl.col("date_decision").dt.month(),
            weekday_decision = pl.col("date_decision").dt.weekday(),
        )
    )
        
    for i, df in enumerate(depth_0 + depth_1 + depth_2):
        df_base = df_base.join(df, how="left", on="case_id", suffix=f"_{i}")
        
    df_base = df_base.pipe(Pipeline.handle_dates)
    
    return df_base

# %%
def to_pandas(df_data, cat_cols=None):
    df_data = df_data.to_pandas()

    # bool型の列をint型に変換
    bool_cols = df_data.select_dtypes('bool').columns
    df_data[bool_cols] = df_data[bool_cols].astype(int)

    if cat_cols is None:
        cat_cols = list(df_data.select_dtypes("object").columns)
    
    df_data[cat_cols] = df_data[cat_cols].astype("category")
    
    return df_data, cat_cols

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        if str(col_type)=="category":
            continue
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            continue
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
ROOT = selector.path
TRAIN_DIR       = ROOT / "parquet_files/train"
TEST_DIR        = ROOT / "parquet_files/test"
SAMPLE_SUB = ROOT / "sample_submission.csv"

# %%
train_data_store = {
    "df_base": read_file(TRAIN_DIR / "train_base.parquet"),
    "depth_0": [
        read_file(TRAIN_DIR / "train_static_cb_0.parquet"),
        read_files(TRAIN_DIR / "train_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TRAIN_DIR / "train_applprev_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_a_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_c_1.parquet", 1),
        read_files(TRAIN_DIR / "train_credit_bureau_a_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_credit_bureau_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_other_1.parquet", 1),
        read_file(TRAIN_DIR / "train_person_1.parquet", 1),
        read_file(TRAIN_DIR / "train_deposit_1.parquet", 1),
        read_file(TRAIN_DIR / "train_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TRAIN_DIR / "train_credit_bureau_b_2.parquet", 2),
        read_files(TRAIN_DIR / "train_credit_bureau_a_2_*.parquet", 2),
    ]
}

# %%
test_data_store = {
    "df_base": read_file(TEST_DIR / "test_base.parquet"),
    "depth_0": [
        read_file(TEST_DIR / "test_static_cb_0.parquet"),
        read_files(TEST_DIR / "test_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TEST_DIR / "test_applprev_1_*.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_a_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_b_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_c_1.parquet", 1),
        read_files(TEST_DIR / "test_credit_bureau_a_1_*.parquet", 1),
        read_file(TEST_DIR / "test_credit_bureau_b_1.parquet", 1),
        read_file(TEST_DIR / "test_other_1.parquet", 1),
        read_file(TEST_DIR / "test_person_1.parquet", 1),
        read_file(TEST_DIR / "test_deposit_1.parquet", 1),
        read_file(TEST_DIR / "test_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TEST_DIR / "test_credit_bureau_b_2.parquet", 2),
        read_files(TEST_DIR / "test_credit_bureau_a_2_*.parquet", 2),
    ]
}

# %%
class DataPreprocessor:
    def __init__(self, df):
        self.df = df

    def select_numerical_columns(self):
        return self.df.select_dtypes(exclude='category').columns

    def calculate_nan_groups(self, nums):
        nans_df = self.df[nums].isna()
        nans_groups = {}
        for col in nums:
            cur_group = nans_df[col].sum()
            nans_groups.setdefault(cur_group, []).append(col)
        del nans_df
        gc.collect()
        return nans_groups

    def reduce_group(self, groups):
        use = []
        for group in groups:
            max_unique = 0
            selected_col = group[0]
            for col in group:
                unique_count = self.df[col].nunique()
                if unique_count > max_unique:
                    max_unique = unique_count
                    selected_col = col
            use.append(selected_col)
        print('Use these:', use)
        return use

    def group_columns_by_correlation(self, matrix, threshold=0.8):
        correlation_matrix = matrix.corr()
        cols = list(matrix.columns)
        groups = []

        while cols:
            base_col = cols.pop(0)
            group = [base_col]
            correlated_cols = [base_col]

            for col in cols:
                if correlation_matrix.loc[base_col, col] >= threshold:
                    group.append(col)
                    correlated_cols.append(col)

            groups.append(group)
            cols = [c for c in cols if c not in correlated_cols]
        
        return groups

    def process_columns(self):
        nums = self.select_numerical_columns()
        nans_groups = self.calculate_nan_groups(nums)
        uses = []

        for count, columns in nans_groups.items():
            if len(columns) > 1:
                grps = self.group_columns_by_correlation(self.df[columns])
                uses += self.reduce_group(grps)
            else:
                uses += columns

            print('####### NAN count =', count)
        
        print('Selected numerical columns:', uses)
        return uses

    def update_dataframe(self):
        uses = self.process_columns()
        uses += list(self.df.select_dtypes(include='category').columns)
        print('Total columns used:', len(uses))
        self.df = self.df[uses]

# %%
df_train = feature_eng(**train_data_store)
print("train data shape:\t", df_train.shape)
del train_data_store
gc.collect()
df_train = df_train.pipe(Pipeline.filter_cols)
df_train, cat_cols = to_pandas(df_train)
df_train = reduce_mem_usage(df_train)
print("train data shape:\t", df_train.shape)

df_test = feature_eng(**test_data_store)
print("test data shape:\t", df_test.shape)
del test_data_store
gc.collect()
df_test = df_test.select([col for col in df_train.columns if col != "target"])
print("train data shape:\t", df_train.shape)
print("test data shape:\t", df_test.shape)

df_test, cat_cols = to_pandas(df_test, cat_cols)
df_test = reduce_mem_usage(df_test)

preprocessor = DataPreprocessor(df_train)
preprocessor.update_dataframe()
# Out:
# train data shape:	 (1526659, 738)
# Memory usage of dataframe is 4858.50 MB
# Memory usage after optimization is: 1967.01 MB
# Decreased by 59.5%
# train data shape:	 (1526659, 519)
# test data shape:	 (10, 737)
# train data shape:	 (1526659, 519)
# test data shape:	 (10, 518)
# Memory usage of dataframe is 0.04 MB
# Memory usage after optimization is: 0.03 MB
# Decreased by 27.8%
# Use these: ['case_id', 'WEEK_NUM', 'target', 'month_decision', 'weekday_decision', 'credamount_770A', 'applicationcnt_361L', 'applications30d_658L', 'applicationscnt_1086L', 'applicationscnt_464L', 'applicationscnt_867L', 'clientscnt_1022L', 'clientscnt_100L', 'clientscnt_1071L', 'clientscnt_1130L', 'clientscnt_157L', 'clientscnt_257L', 'clientscnt_304L', 'clientscnt_360L', 'clientscnt_493L', 'clientscnt_533L', 'clientscnt_887L', 'clientscnt_946L', 'deferredmnthsnum_166L', 'disbursedcredamount_1113A', 'downpmt_116A', 'homephncnt_628L', 'isbidproduct_1095L', 'mobilephncnt_593L', 'numactivecreds_622L', 'numactivecredschannel_414L', 'numactiverelcontr_750L', 'numcontrs3months_479L', 'numnotactivated_1143L', 'numpmtchanneldd_318L', 'numrejects9m_859L', 'sellerplacecnt_915L', 'max_mainoccupationinc_384A', 'min_birth_259D', 'max_num_group1_9']
# ####### NAN count = 0
# ####### NAN count = 1389663
# Use these: ['assignmentdate_4527235D', 'pmtaverage_4527227A', 'pmtcount_4527229L']
# ####### NAN count = 1411681
# ####### NAN count = 918788
# Use these: ['contractssum_5085716L']
# ####### NAN count = 1369330
# Use these: ['dateofbirth_337D', 'days180_256L', 'days30_165L', 'days360_512L', 'firstquarter_103L', 'fourthquarter_440L', 'secondquarter_766L', 'thirdquarter_1082L', 'max_debtoutstand_525A', 'max_debtoverdue_47A', 'min_refreshdate_3813885D', 'max_refreshdate_3813885D']
# ####### NAN count = 140968
# ####### NAN count = 1383070
# ####### NAN count = 1380253
# Use these: ['pmtscount_423L', 'pmtssum_45A']
# ####### NAN count = 954021
# ####### NAN count = 806659
# ####### NAN count = 866332
# ####### NAN count = 1301747
# ####### NAN count = 418178
# Use these: ['amtinstpaidbefduel24m_4187115A', 'numinstlswithdpd5_4187116L']
# ####### NAN count = 561124
# Use these: ['annuitynextmonth_57A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'numinstls_657L', 'totalsettled_863A']
# ####### NAN count = 4
# Use these: ['mindbddpdlast24m_3658935P']
# ####### NAN count = 613202
# ####### NAN count = 948244
# Use these: ['mindbdtollast24m_4525191P']
# ####### NAN count = 972827
# ####### NAN count = 467175
# Use these: ['avginstallast24m_3658937A', 'maxinstallast24m_3658928A']
# ####### NAN count = 624875
# ####### NAN count = 1364150
# ####### NAN count = 757006
# ####### NAN count = 841181
# ####### NAN count = 1026987
# ####### NAN count = 455190
# ####### NAN count = 460822
# Use these: ['commnoinclast6m_3546845L', 'maxdpdfrom6mto36m_3546853P']
# ####### NAN count = 343375
# ####### NAN count = 833735
# ####### NAN count = 1392841
# ####### NAN count = 887659
# Use these: ['daysoverduetolerancedd_3976961L', 'numinsttopaygr_769L']
# ####### NAN count = 452594
# ####### NAN count = 977119
# Use these: ['eir_270L']
# ####### NAN count = 190833
# ####### NAN count = 859214
# ####### NAN count = 482103
# ####### NAN count = 1334357
# ####### NAN count = 453587
# Use these: ['lastapplicationdate_877D', 'min_creationdate_885D', 'max_num_group1']
# ####### NAN count = 305137
# Use these: ['lastapprcredamount_781A', 'lastapprdate_640D']
# ####### NAN count = 442041
# ####### NAN count = 977975
# Use these: ['lastrejectcredamount_222A', 'lastrejectdate_50D']
# ####### NAN count = 769046
# ####### NAN count = 511255
# Use these: ['mastercontrelectronic_519L', 'mastercontrexist_109L', 'maxannuity_159A', 'maxdebt4_972A', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdtolerance_374P']
# ####### NAN count = 306019
# ####### NAN count = 960953
# ####### NAN count = 705504
# ####### NAN count = 876276
# ####### NAN count = 826000
# ####### NAN count = 829402
# ####### NAN count = 1032856
# ####### NAN count = 766958
# ####### NAN count = 1129330
# Use these: ['numinstpaidearly_338L', 'numinstpaidearly5d_1087L', 'numinstpaidlate1d_3546852L']
# ####### NAN count = 452593
# ####### NAN count = 455081
# Use these: ['numinstlsallpaid_934L']
# ####### NAN count = 445669
# Use these: ['numinstlswithdpd10_728L', 'numinstlswithoutdpd_562L']
# ####### NAN count = 456495
# Use these: ['numinstpaid_4499208L']
# ####### NAN count = 847191
# ####### NAN count = 446983
# Use these: ['numinstregularpaidest_4493210L', 'numinstpaidearly5dest_4493211L', 'sumoutstandtotalest_4493215A']
# ####### NAN count = 840646
# ####### NAN count = 669186
# ####### NAN count = 455612
# Use these: ['pctinstlsallpaidearl3d_427L', 'pctinstlsallpaidlate1d_3546856L']
# ####### NAN count = 458738
# ####### NAN count = 461362
# ####### NAN count = 459827
# ####### NAN count = 460079
# ####### NAN count = 44954
# ####### NAN count = 78526
# ####### NAN count = 131888
# ####### NAN count = 181122
# ####### NAN count = 223240
# ####### NAN count = 445320
# ####### NAN count = 3
# ####### NAN count = 1174211
# ####### NAN count = 1374886
# Use these: ['mean_actualdpd_943P', 'min_actualdpd_943P']
# ####### NAN count = 305154
# Use these: ['max_annuity_853A', 'min_annuity_853A', 'mean_annuity_853A']
# ####### NAN count = 308739
# Use these: ['mean_credacc_actualbalance_314A', 'mean_credacc_maxhisbal_375A', 'mean_credacc_minhisbal_90A', 'max_credacc_transactions_402L']
# ####### NAN count = 1273086
# Use these: ['max_credacc_credlmt_575A', 'max_credamount_590A', 'max_downpmt_134A', 'min_credacc_credlmt_575A', 'min_credamount_590A', 'min_downpmt_134A', 'mean_credacc_credlmt_575A', 'mean_credamount_590A', 'mean_downpmt_134A']
# ####### NAN count = 307441
# Use these: ['max_currdebt_94A', 'min_currdebt_94A', 'mean_currdebt_94A']
# ####### NAN count = 419006
# Use these: ['max_mainoccupationinc_437A', 'min_mainoccupationinc_437A', 'mean_mainoccupationinc_437A']
# ####### NAN count = 306361
# Use these: ['mean_maxdpdtolerance_577P', 'min_maxdpdtolerance_577P']
# ####### NAN count = 450969
# Use these: ['max_outstandingdebt_522A', 'min_outstandingdebt_522A', 'mean_outstandingdebt_522A']
# ####### NAN count = 420383
# Use these: ['mean_revolvingaccount_394A']
# ####### NAN count = 1273082
# ####### NAN count = 535095
# ####### NAN count = 543674
# ####### NAN count = 539780
# Use these: ['std_credamount_590A', 'std_downpmt_134A']
# ####### NAN count = 540212
# ####### NAN count = 701318
# ####### NAN count = 538908
# ####### NAN count = 759462
# ####### NAN count = 702928
# Use these: ['min_approvaldate_319D', 'max_approvaldate_319D']
# ####### NAN count = 442999
# Use these: ['min_dateactivated_425D', 'max_dateactivated_425D']
# ####### NAN count = 454678
# Use these: ['min_dtlastpmt_581D', 'max_dtlastpmt_581D']
# ####### NAN count = 703840
# Use these: ['min_dtlastpmtallstes_3545839D', 'max_dtlastpmtallstes_3545839D']
# ####### NAN count = 548987
# Use these: ['max_employedfrom_700D']
# ####### NAN count = 559169
# Use these: ['min_firstnonzeroinstldate_307D', 'max_firstnonzeroinstldate_307D']
# ####### NAN count = 334873
# ####### NAN count = 961606
# ####### NAN count = 552766
# Use these: ['max_pmtnum_8L']
# ####### NAN count = 321446
# Use these: ['max_amount_4527230A', 'min_amount_4527230A', 'min_recorddate_4527225D', 'max_num_group1_3']
# ####### NAN count = 1068725
# ####### NAN count = 1085243
# Use these: ['mean_amount_4917619A', 'min_amount_4917619A', 'min_deductiondate_4917603D', 'max_deductiondate_4917603D', 'max_num_group1_4']
# ####### NAN count = 1375927
# ####### NAN count = 1377449
# Use these: ['max_pmtamount_36A', 'min_pmtamount_36A', 'min_processingdate_168D', 'max_processingdate_168D', 'max_num_group1_5']
# ####### NAN count = 1044394
# ####### NAN count = 1063483
# Use these: ['mean_credlmt_230A', 'min_credlmt_230A']
# ####### NAN count = 1036944
# Use these: ['mean_credlmt_935A', 'min_credlmt_935A']
# ####### NAN count = 603001
# Use these: ['mean_pmts_dpd_1073P', 'min_dpdmax_139P', 'max_dpdmaxdatemonth_89T', 'max_dpdmaxdateyear_596T']
# ####### NAN count = 263166
# Use these: ['max_pmts_dpd_303P', 'min_dpdmax_757P', 'mean_dpdmax_757P', 'max_dpdmaxdatemonth_442T', 'max_dpdmaxdateyear_896T', 'min_pmts_dpd_303P', 'mean_pmts_dpd_303P']
# ####### NAN count = 514070
# Use these: ['mean_instlamount_768A', 'min_instlamount_768A']
# ####### NAN count = 606920
# Use these: ['mean_instlamount_852A', 'min_instlamount_852A']
# ####### NAN count = 1136162
# Use these: ['mean_monthlyinstlamount_332A', 'min_monthlyinstlamount_332A']
# ####### NAN count = 263233
# Use these: ['max_monthlyinstlamount_674A', 'min_monthlyinstlamount_674A', 'mean_monthlyinstlamount_674A']
# ####### NAN count = 517511
# Use these: ['mean_outstandingamount_354A', 'min_outstandingamount_354A']
# ####### NAN count = 545885
# Use these: ['mean_outstandingamount_362A']
# ####### NAN count = 636453
# Use these: ['mean_overdueamount_31A', 'min_overdueamount_31A']
# ####### NAN count = 512650
# Use these: ['mean_overdueamount_659A', 'min_overdueamount_659A', 'max_numberofoverdueinstls_725L']
# ####### NAN count = 263171
# Use these: ['mean_overdueamountmax2_14A', 'mean_totaloutstanddebtvalue_39A', 'min_overdueamountmax2_14A', 'min_totaldebtoverduevalue_178A', 'min_totaloutstanddebtvalue_39A', 'min_dateofcredend_289D', 'min_dateofcredstart_739D', 'min_lastupdate_1112D', 'max_dateofcredend_289D', 'max_dateofcredstart_739D', 'max_lastupdate_1112D', 'max_numberofcontrsvalue_258L', 'max_numberofoverdueinstlmax_1039L', 'max_overdueamountmaxdatemonth_365T', 'max_overdueamountmaxdateyear_2T', 'min_pmts_overdue_1140A', 'mean_pmts_overdue_1140A', 'max_pmts_month_158T', 'max_pmts_year_1139T']
# ####### NAN count = 262653
# Use these: ['mean_overdueamountmax2_398A', 'min_overdueamountmax2_398A', 'min_dateofcredend_353D', 'max_dateofcredend_353D', 'max_dateofcredstart_181D', 'max_numberofoverdueinstlmax_1151L']
# ####### NAN count = 512590
# Use these: ['mean_overdueamountmax_35A', 'min_overdueamountmax_35A', 'max_overdueamountmaxdatemonth_284T', 'max_overdueamountmaxdateyear_994T', 'min_pmts_overdue_1152A', 'mean_pmts_overdue_1152A']
# ####### NAN count = 513987
# Use these: ['max_residualamount_488A']
# ####### NAN count = 1039597
# Use these: ['mean_residualamount_856A', 'min_residualamount_856A']
# ####### NAN count = 606900
# Use these: ['max_totalamount_6A', 'mean_totalamount_6A']
# ####### NAN count = 545855
# Use these: ['mean_totalamount_996A']
# ####### NAN count = 636448
# Use these: ['mean_totaldebtoverduevalue_718A', 'mean_totaloutstanddebtvalue_668A', 'min_totaloutstanddebtvalue_668A', 'max_numberofcontrsvalue_358L']
# ####### NAN count = 297072
# ####### NAN count = 1308268
# ####### NAN count = 1246089
# ####### NAN count = 729184
# ####### NAN count = 654687
# ####### NAN count = 1253365
# ####### NAN count = 1400301
# ####### NAN count = 729342
# ####### NAN count = 661628
# ####### NAN count = 698560
# ####### NAN count = 1160503
# ####### NAN count = 650655
# ####### NAN count = 729205
# ####### NAN count = 727677
# ####### NAN count = 650524
# ####### NAN count = 727678
# ####### NAN count = 654541
# ####### NAN count = 1310473
# ####### NAN count = 1253324
# ####### NAN count = 698532
# ####### NAN count = 1160489
# Use these: ['min_dateofrealrepmt_138D', 'max_dateofrealrepmt_138D']
# ####### NAN count = 512961
# Use these: ['min_lastupdate_388D', 'max_lastupdate_388D']
# ####### NAN count = 512591
# Use these: ['min_numberofoverdueinstlmaxdat_148D', 'max_numberofoverdueinstlmaxdat_148D']
# ####### NAN count = 802351
# Use these: ['min_numberofoverdueinstlmaxdat_641D']
# ####### NAN count = 1012361
# Use these: ['min_overdueamountmax2date_1002D', 'max_overdueamountmax2date_1002D']
# ####### NAN count = 806653
# Use these: ['min_overdueamountmax2date_1142D']
# ####### NAN count = 1007594
# ####### NAN count = 1237917
# ####### NAN count = 1270160
# ####### NAN count = 822517
# ####### NAN count = 745109
# ####### NAN count = 545898
# ####### NAN count = 636545
# ####### NAN count = 545895
# ####### NAN count = 636544
# ####### NAN count = 512657
# ####### NAN count = 561307
# ####### NAN count = 649082
# ####### NAN count = 1436524
# ####### NAN count = 140386
# Use these: ['min_empl_employedfrom_271D']
# ####### NAN count = 959958
# Use these: ['mean_amount_416A', 'min_amount_416A', 'min_openingdate_313D', 'max_num_group1_10']
# ####### NAN count = 1421548
# Use these: ['min_openingdate_857D']
# ####### NAN count = 1421572
# ####### NAN count = 1414887
# ####### NAN count = 274257
# ####### NAN count = 517831
# ####### NAN count = 273700
# ####### NAN count = 517731
# ####### NAN count = 262659
# ####### NAN count = 512884
# Use these: ['max_pmts_month_706T', 'max_pmts_year_507T']
# ####### NAN count = 512598
# Use these: ['max_num_group1_13', 'max_num_group2_13']
# ####### NAN count = 141371
# Selected numerical columns: ['case_id', 'WEEK_NUM', 'target', 'month_decision', 'weekday_decision', 'credamount_770A', 'applicationcnt_361L', 'applications30d_658L', 'applicationscnt_1086L', 'applicationscnt_464L', 'applicationscnt_867L', 'clientscnt_1022L', 'clientscnt_100L', 'clientscnt_1071L', 'clientscnt_1130L', 'clientscnt_157L', 'clientscnt_257L', 'clientscnt_304L', 'clientscnt_360L', 'clientscnt_493L', 'clientscnt_533L', 'clientscnt_887L', 'clientscnt_946L', 'deferredmnthsnum_166L', 'disbursedcredamount_1113A', 'downpmt_116A', 'homephncnt_628L', 'isbidproduct_1095L', 'mobilephncnt_593L', 'numactivecreds_622L', 'numactivecredschannel_414L', 'numactiverelcontr_750L', 'numcontrs3months_479L', 'numnotactivated_1143L', 'numpmtchanneldd_318L', 'numrejects9m_859L', 'sellerplacecnt_915L', 'max_mainoccupationinc_384A', 'min_birth_259D', 'max_num_group1_9', 'assignmentdate_238D', 'assignmentdate_4527235D', 'pmtaverage_4527227A', 'pmtcount_4527229L', 'birthdate_574D', 'contractssum_5085716L', 'dateofbirth_337D', 'days180_256L', 'days30_165L', 'days360_512L', 'firstquarter_103L', 'fourthquarter_440L', 'secondquarter_766L', 'thirdquarter_1082L', 'max_debtoutstand_525A', 'max_debtoverdue_47A', 'min_refreshdate_3813885D', 'max_refreshdate_3813885D', 'pmtaverage_3A', 'pmtcount_693L', 'pmtscount_423L', 'pmtssum_45A', 'responsedate_1012D', 'responsedate_4527233D', 'responsedate_4917613D', 'actualdpdtolerance_344P', 'amtinstpaidbefduel24m_4187115A', 'numinstlswithdpd5_4187116L', 'annuitynextmonth_57A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'numinstls_657L', 'totalsettled_863A', 'mindbddpdlast24m_3658935P', 'avgdbddpdlast3m_4187120P', 'mindbdtollast24m_4525191P', 'avgdpdtolclosure24_3658938P', 'avginstallast24m_3658937A', 'maxinstallast24m_3658928A', 'avglnamtstart24m_4525187A', 'avgmaxdpdlast9m_3716943P', 'avgoutstandbalancel6m_4187114A', 'avgpmtlast12m_4525200A', 'cntincpaycont9m_3716944L', 'cntpmts24_3658933L', 'commnoinclast6m_3546845L', 'maxdpdfrom6mto36m_3546853P', 'datefirstoffer_1144D', 'datelastinstal40dpd_247D', 'datelastunpaid_3546854D', 'daysoverduetolerancedd_3976961L', 'numinsttopaygr_769L', 'dtlastpmtallstes_4499206D', 'eir_270L', 'firstclxcampaign_1125D', 'firstdatedue_489D', 'inittransactionamount_650A', 'lastactivateddate_801D', 'lastapplicationdate_877D', 'min_creationdate_885D', 'max_num_group1', 'lastapprcredamount_781A', 'lastapprdate_640D', 'lastdelinqdate_224D', 'lastrejectcredamount_222A', 'lastrejectdate_50D', 'maininc_215A', 'mastercontrelectronic_519L', 'mastercontrexist_109L', 'maxannuity_159A', 'maxdebt4_972A', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdtolerance_374P', 'maxdbddpdlast1m_3658939P', 'maxdbddpdtollast12m_3658940P', 'maxdbddpdtollast6m_4187119P', 'maxdpdinstldate_3546855D', 'maxdpdinstlnum_3546846P', 'maxlnamtstart6m_4525199A', 'maxoutstandbalancel12m_4187113A', 'maxpmtlast3m_4525190A', 'numinstpaidearly_338L', 'numinstpaidearly5d_1087L', 'numinstpaidlate1d_3546852L', 'numincomingpmts_3546848L', 'numinstlsallpaid_934L', 'numinstlswithdpd10_728L', 'numinstlswithoutdpd_562L', 'numinstpaid_4499208L', 'numinstpaidearly3d_3546850L', 'numinstregularpaidest_4493210L', 'numinstpaidearly5dest_4493211L', 'sumoutstandtotalest_4493215A', 'numinstpaidlastcontr_4325080L', 'numinstregularpaid_973L', 'pctinstlsallpaidearl3d_427L', 'pctinstlsallpaidlate1d_3546856L', 'pctinstlsallpaidlat10d_839L', 'pctinstlsallpaidlate4d_3546849L', 'pctinstlsallpaidlate6d_3546844L', 'pmtnum_254L', 'posfpd10lastmonth_333P', 'posfpd30lastmonth_3976960P', 'posfstqpd30lastmonth_3976962P', 'price_1097A', 'sumoutstandtotal_3546847A', 'totaldebt_9A', 'totinstallast1m_4525188A', 'validfrom_1069D', 'mean_actualdpd_943P', 'min_actualdpd_943P', 'max_annuity_853A', 'min_annuity_853A', 'mean_annuity_853A', 'mean_credacc_actualbalance_314A', 'mean_credacc_maxhisbal_375A', 'mean_credacc_minhisbal_90A', 'max_credacc_transactions_402L', 'max_credacc_credlmt_575A', 'max_credamount_590A', 'max_downpmt_134A', 'min_credacc_credlmt_575A', ...
# Total columns used: 425

# %%
df_train = df_train.sample(frac=0.01)

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
def check_ADF(df, exclude_cols=None, exclude_prefixes=None, batch_size=10):
    if exclude_cols is None:
        exclude_cols = ["case_id", "WEEK_NUM"]
    if exclude_prefixes is None:
        exclude_prefixes = ['max_', 'min_', 'mean_', 'std_']

    # CFG.target_col が定義されていることを確認（外部設定が必要）
    target_col = CFG.target_col

    # 特定のカラムとプレフィックスを除外
    features = [col for col in df.columns if col not in exclude_cols and col != target_col and not any(col.startswith(prefix) for prefix in exclude_prefixes)]
    numeric_feats = df[features].select_dtypes(include=[np.number]).columns

    # 特徴量をバッチに分割
    batches = np.array_split(numeric_feats, np.ceil(len(numeric_feats) / batch_size))

    for batch in batches:
        for feat in batch:
            try:
                result = adfuller(df[feat].dropna())
                print(f'Feature: {feat}')
                print('ADF Statistic: %f' % result[0])
                print('p-value: %f' % result[1])
                print('Critical Values:')
                for key, value in result[4].items():
                    print(f'\t{key}: {value:.3f}')
                if result[1] < 0.05:
                    print("データは定常と判断されます。\n")
                else:
                    print("データは非定常と判断されます。\n")
            except Exception as e:
                print(f"Feature {feat} failed due to an error: {e}")
            finally:
                gc.collect()  # 各特徴量の処理後にガーベージコレクション

check_ADF(df_train)
gc.collect()
# Out:
# Feature: month_decision
# ADF Statistic: -44.402027
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: weekday_decision
# ADF Statistic: -122.556036
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: assignmentdate_238D
# ADF Statistic: -36.866256
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: assignmentdate_4527235D
# ADF Statistic: -34.692753
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: birthdate_574D
# ADF Statistic: -78.463352
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: contractssum_5085716L
# ADF Statistic: -41.162345
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: dateofbirth_337D
# ADF Statistic: -117.703228
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: days120_123L
# ADF Statistic: -117.403914
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: days180_256L
# ADF Statistic: -47.085535
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: days30_165L
# ADF Statistic: -115.441330
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: days360_512L
# ADF Statistic: -29.643486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: days90_310L
# ADF Statistic: -118.289255
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: firstquarter_103L
# ADF Statistic: -25.962877
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: fourthquarter_440L
# ADF Statistic: -66.778915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numberofqueries_373L
# ADF Statistic: -29.643486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pmtaverage_3A
# ADF Statistic: -27.829048
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: pmtaverage_4527227A
# ADF Statistic: -34.892705
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: pmtcount_4527229L
# ADF Statistic: -35.520882
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: pmtcount_693L
# ADF Statistic: -37.361630
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: pmtscount_423L
# ADF Statistic: -73.873059
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pmtssum_45A
# ADF Statistic: -74.111857
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: responsedate_1012D
# ADF Statistic: -85.520064
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: responsedate_4527233D
# ADF Statistic: -81.145099
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: responsedate_4917613D
# ADF Statistic: -48.020256
# p-value: 0.000000
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: secondquarter_766L
# ADF Statistic: -53.061889
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: thirdquarter_1082L
# ADF Statistic: -119.153809
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: actualdpdtolerance_344P
# ADF Statistic: -105.538486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: amtinstpaidbefduel24m_4187115A
# ADF Statistic: -70.982915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: annuity_780A
# ADF Statistic: -123.463616
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: annuitynextmonth_57A
# ADF Statistic: -124.328884
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applicationcnt_361L
# ADF Statistic: -123.555655
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applications30d_658L
# ADF Statistic: -86.590415
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applicationscnt_1086L
# ADF Statistic: -124.204700
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applicationscnt_464L
# ADF Statistic: -123.537071
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applicationscnt_629L
# ADF Statistic: -123.935579
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: applicationscnt_867L
# ADF Statistic: -48.808033
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgdbddpdlast24m_3658932P
# ADF Statistic: -66.860698
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgdbddpdlast3m_4187120P
# ADF Statistic: -76.074162
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgdbdtollast24m_4525197P
# ADF Statistic: -74.669449
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgdpdtolclosure24_3658938P
# ADF Statistic: -103.482008
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avginstallast24m_3658937A
# ADF Statistic: -95.559312
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avglnamtstart24m_4525187A
# ADF Statistic: -41.667922
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: avgmaxdpdlast9m_3716943P
# ADF Statistic: -87.241575
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgoutstandbalancel6m_4187114A
# ADF Statistic: -60.326593
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: avgpmtlast12m_4525200A
# ADF Statistic: -72.730730
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt12m_3712952L
# ADF Statistic: -85.897685
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt3m_3712950L
# ADF Statistic: -123.315159
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt6m_3712949L
# ADF Statistic: -123.622093
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_100L
# ADF Statistic: -124.987975
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_1022L
# ADF Statistic: -124.235088
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_1071L
# ADF Statistic: -123.347921
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_1130L
# ADF Statistic: -53.281240
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_157L
# ADF Statistic: -49.215754
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_257L
# ADF Statistic: -123.867344
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_304L
# ADF Statistic: -124.292423
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_360L
# ADF Statistic: -68.455343
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_493L
# ADF Statistic: -123.607273
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_533L
# ADF Statistic: -89.156396
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_887L
# ADF Statistic: -121.549306
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: clientscnt_946L
# ADF Statistic: -123.822670
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: cntincpaycont9m_3716944L
# ADF Statistic: -58.586243
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: cntpmts24_3658933L
# ADF Statistic: -74.232424
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature commnoinclast6m_3546845L failed due to an error: Invalid input, x is constant
# Feature: credamount_770A
# ADF Statistic: -124.372732
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: currdebt_22A
# ADF Statistic: -124.426503
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: currdebtcredtyperange_828A
# ADF Statistic: -123.609750
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: datefirstoffer_1144D
# ADF Statistic: -82.031035
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: datelastinstal40dpd_247D
# ADF Statistic: -35.919087
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: datelastunpaid_3546854D
# ADF Statistic: -48.070923
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: daysoverduetolerancedd_3976961L
# ADF Statistic: -34.184141
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature deferredmnthsnum_166L failed due to an error: Invalid input, x is constant
# Feature: disbursedcredamount_1113A
# ADF Statistic: -123.932306
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: downpmt_116A
# ADF Statistic: -124.771219
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: dtlastpmtallstes_4499206D
# ADF Statistic: -74.158267
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: eir_270L
# ADF Statistic: -114.347290
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: firstclxcampaign_1125D
# ADF Statistic: -80.466733
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: firstdatedue_489D
# ADF Statistic: -102.471637
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: homephncnt_628L
# ADF Statistic: -122.833366
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: inittransactionamount_650A
# ADF Statistic: -44.878332
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# Feature: interestrate_311L
# ADF Statistic: -114.347290
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: isbidproduct_1095L
# ADF Statistic: -51.601712
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastactivateddate_801D
# ADF Statistic: -102.850913
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastapplicationdate_877D
# ADF Statistic: -110.123580
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastapprcredamount_781A
# ADF Statistic: -62.113064
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastapprdate_640D
# ADF Statistic: -103.579577
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastdelinqdate_224D
# ADF Statistic: -38.860437
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastrejectcredamount_222A
# ADF Statistic: -87.668032
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: lastrejectdate_50D
# ADF Statistic: -85.792100
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maininc_215A
# ADF Statistic: -101.673921
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature mastercontrelectronic_519L failed due to an error: Invalid input, x is constant
# Feature mastercontrexist_109L failed due to an error: Invalid input, x is constant
# Feature: maxannuity_159A
# ADF Statistic: -77.173003
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdbddpdlast1m_3658939P
# ADF Statistic: -75.799076
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdbddpdtollast12m_3658940P
# ADF Statistic: -63.040610
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdbddpdtollast6m_4187119P
# ADF Statistic: -80.751626
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdebt4_972A
# ADF Statistic: -80.200782
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdfrom6mto36m_3546853P
# ADF Statistic: -110.130132
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdinstldate_3546855D
# ADF Statistic: -42.088217
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdinstlnum_3546846P
# ADF Statistic: -58.113273
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdlast12m_727P
# ADF Statistic: -77.431880
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdlast24m_143P
# ADF Statistic: -111.779672
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdlast3m_392P
# ADF Statistic: -111.014312
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdlast6m_474P
# ADF Statistic: -76.463385
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdlast9m_1059P
# ADF Statistic: -76.828199
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxdpdtolerance_374P
# ADF Statistic: -111.263098
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxinstallast24m_3658928A
# ADF Statistic: -95.499946
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxlnamtstart6m_4525199A
# ADF Statistic: -71.960363
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxoutstandbalancel12m_4187113A
# ADF Statistic: -89.978547
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: maxpmtlast3m_4525190A
# ADF Statistic: -36.955039
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: mindbddpdlast24m_3658935P
# ADF Statistic: -96.758143
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: mindbdtollast24m_4525191P
# ADF Statistic: -75.234896
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: mobilephncnt_593L
# ADF Statistic: -124.450801
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: monthsannuity_845L
# ADF Statistic: -102.332117
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numactivecreds_622L
# ADF Statistic: -85.934583
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numactivecredschannel_414L
# ADF Statistic: -85.075036
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numactiverelcontr_750L
# ADF Statistic: -124.155476
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numcontrs3months_479L
# ADF Statistic: -37.465687
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numincomingpmts_3546848L
# ADF Statistic: -102.453223
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstlallpaidearly3d_817L
# ADF Statistic: -45.639506
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstls_657L
# ADF Statistic: -88.276149
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstlsallpaid_934L
# ADF Statistic: -102.870932
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstlswithdpd10_728L
# ADF Statistic: -102.589804
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstlswithdpd5_4187116L
# ADF Statistic: -97.770364
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstlswithoutdpd_562L
# ADF Statistic: -45.254028
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstmatpaidtearly2d_4499204L
# ADF Statistic: -81.182139
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaid_4499208L
# ADF Statistic: -81.660100
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly3d_3546850L
# ADF Statistic: -102.256951
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly3dest_4493216L
# ADF Statistic: -81.573588
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly5d_1087L
# ADF Statistic: -102.433180
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly5dest_4493211L
# ADF Statistic: -83.242436
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly5dobd_4499205L
# ADF Statistic: -81.083750
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearly_338L
# ADF Statistic: -45.265728
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidearlyest_4493214L
# ADF Statistic: -81.686741
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidlastcontr_4325080L
# ADF Statistic: -93.714406
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstpaidlate1d_3546852L
# ADF Statistic: -103.002427
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstregularpaid_973L
# ADF Statistic: -102.854682
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstregularpaidest_4493210L
# ADF Statistic: -82.139118
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinsttopaygr_769L
# ADF Statistic: -46.661126
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinsttopaygrest_4493213L
# ADF Statistic: -46.978578
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstunpaidmax_3546851L
# ADF Statistic: -46.719862
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numinstunpaidmaxest_4493212L
# ADF Statistic: -46.830546
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numnotactivated_1143L
# ADF Statistic: -124.648826
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numpmtchanneldd_318L
# ADF Statistic: -124.632380
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: numrejects9m_859L
# ADF Statistic: -48.265356
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pctinstlsallpaidearl3d_427L
# ADF Statistic: -28.966915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pctinstlsallpaidlat10d_839L
# ADF Statistic: -103.684820
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pctinstlsallpaidlate1d_3546856L
# ADF Statistic: -72.310412
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pctinstlsallpaidlate4d_3546849L
# ADF Statistic: -103.865372
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pctinstlsallpaidlate6d_3546844L
# ADF Statistic: -103.647960
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: pmtnum_254L
# ADF Statistic: -121.733719
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: posfpd10lastmonth_333P
# ADF Statistic: -121.089186
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: posfpd30lastmonth_3976960P
# ADF Statistic: -118.852616
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: posfstqpd30lastmonth_3976962P
# ADF Statistic: -114.823143
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: price_1097A
# ADF Statistic: -115.153458
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: sellerplacecnt_915L
# ADF Statistic: -123.215900
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: sellerplacescnt_216L
# ADF Statistic: -40.409343
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: sumoutstandtotal_3546847A
# ADF Statistic: -75.205831
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: sumoutstandtotalest_4493215A
# ADF Statistic: -84.702700
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: totaldebt_9A
# ADF Statistic: -124.421553
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: totalsettled_863A
# ADF Statistic: -122.429960
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: totinstallast1m_4525188A
# ADF Statistic: -60.027049
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# Feature: validfrom_1069D
# ADF Statistic: -39.265114
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
# 0

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller

def check_ADF(df, exclude_cols=None, exclude_prefixes=None):
    if exclude_cols is None:
        exclude_cols = ["case_id", "WEEK_NUM"]
    if exclude_prefixes is None:
        exclude_prefixes = ['max_', 'min_', 'mean_', 'std_']

    features = [col for col in df.columns if col not in exclude_cols and col != CFG.target_col and not any(col.startswith(prefix) for prefix in exclude_prefixes)]
    numeric_feats = df[features].select_dtypes(include=[np.number]).columns

    for feat in numeric_feats:
        print(feat)
        try:
            result = adfuller(df[feat].dropna())
            print(f'Feature: {feat}')
            print('ADF Statistic: %f' % result[0])
            print('p-value: %f' % result[1])
            print('Critical Values:')
            for key, value in result[4].items():
                print(f'\t{key}: {value:.3f}')
            if result[1] < 0.05:
                print("データは定常と判断されます。\n")
            else:
                print("データは非定常と判断されます。\n")
        except Exception as e:
            print(f"Feature {feat} failed due to an error: {e}")

# データフレーム `df_train` を適切に定義して使用
check_ADF(df_train)
gc.collect()
# Out:
# month_decision
# Feature: month_decision
# ADF Statistic: -44.402027
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# weekday_decision
# Feature: weekday_decision
# ADF Statistic: -122.556036
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# assignmentdate_238D
# Feature: assignmentdate_238D
# ADF Statistic: -36.866256
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# assignmentdate_4527235D
# Feature: assignmentdate_4527235D
# ADF Statistic: -34.692753
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# birthdate_574D
# Feature: birthdate_574D
# ADF Statistic: -78.463352
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# contractssum_5085716L
# Feature: contractssum_5085716L
# ADF Statistic: -41.162345
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# dateofbirth_337D
# Feature: dateofbirth_337D
# ADF Statistic: -117.703228
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# days120_123L
# Feature: days120_123L
# ADF Statistic: -117.403914
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# days180_256L
# Feature: days180_256L
# ADF Statistic: -47.085535
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# days30_165L
# Feature: days30_165L
# ADF Statistic: -115.441330
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# days360_512L
# Feature: days360_512L
# ADF Statistic: -29.643486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# days90_310L
# Feature: days90_310L
# ADF Statistic: -118.289255
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# firstquarter_103L
# Feature: firstquarter_103L
# ADF Statistic: -25.962877
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# fourthquarter_440L
# Feature: fourthquarter_440L
# ADF Statistic: -66.778915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numberofqueries_373L
# Feature: numberofqueries_373L
# ADF Statistic: -29.643486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pmtaverage_3A
# Feature: pmtaverage_3A
# ADF Statistic: -27.829048
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# pmtaverage_4527227A
# Feature: pmtaverage_4527227A
# ADF Statistic: -34.892705
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# pmtcount_4527229L
# Feature: pmtcount_4527229L
# ADF Statistic: -35.520882
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# pmtcount_693L
# Feature: pmtcount_693L
# ADF Statistic: -37.361630
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# pmtscount_423L
# Feature: pmtscount_423L
# ADF Statistic: -73.873059
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pmtssum_45A
# Feature: pmtssum_45A
# ADF Statistic: -74.111857
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# responsedate_1012D
# Feature: responsedate_1012D
# ADF Statistic: -85.520064
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# responsedate_4527233D
# Feature: responsedate_4527233D
# ADF Statistic: -81.145099
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# responsedate_4917613D
# Feature: responsedate_4917613D
# ADF Statistic: -48.020256
# p-value: 0.000000
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# データは定常と判断されます。
#
# secondquarter_766L
# Feature: secondquarter_766L
# ADF Statistic: -53.061889
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# thirdquarter_1082L
# Feature: thirdquarter_1082L
# ADF Statistic: -119.153809
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# actualdpdtolerance_344P
# Feature: actualdpdtolerance_344P
# ADF Statistic: -105.538486
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# amtinstpaidbefduel24m_4187115A
# Feature: amtinstpaidbefduel24m_4187115A
# ADF Statistic: -70.982915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# annuity_780A
# Feature: annuity_780A
# ADF Statistic: -123.463616
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# annuitynextmonth_57A
# Feature: annuitynextmonth_57A
# ADF Statistic: -124.328884
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applicationcnt_361L
# Feature: applicationcnt_361L
# ADF Statistic: -123.555655
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applications30d_658L
# Feature: applications30d_658L
# ADF Statistic: -86.590415
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applicationscnt_1086L
# Feature: applicationscnt_1086L
# ADF Statistic: -124.204700
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applicationscnt_464L
# Feature: applicationscnt_464L
# ADF Statistic: -123.537071
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applicationscnt_629L
# Feature: applicationscnt_629L
# ADF Statistic: -123.935579
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# applicationscnt_867L
# Feature: applicationscnt_867L
# ADF Statistic: -48.808033
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgdbddpdlast24m_3658932P
# Feature: avgdbddpdlast24m_3658932P
# ADF Statistic: -66.860698
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgdbddpdlast3m_4187120P
# Feature: avgdbddpdlast3m_4187120P
# ADF Statistic: -76.074162
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgdbdtollast24m_4525197P
# Feature: avgdbdtollast24m_4525197P
# ADF Statistic: -74.669449
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgdpdtolclosure24_3658938P
# Feature: avgdpdtolclosure24_3658938P
# ADF Statistic: -103.482008
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avginstallast24m_3658937A
# Feature: avginstallast24m_3658937A
# ADF Statistic: -95.559312
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avglnamtstart24m_4525187A
# Feature: avglnamtstart24m_4525187A
# ADF Statistic: -41.667922
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# avgmaxdpdlast9m_3716943P
# Feature: avgmaxdpdlast9m_3716943P
# ADF Statistic: -87.241575
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgoutstandbalancel6m_4187114A
# Feature: avgoutstandbalancel6m_4187114A
# ADF Statistic: -60.326593
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# avgpmtlast12m_4525200A
# Feature: avgpmtlast12m_4525200A
# ADF Statistic: -72.730730
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt12m_3712952L
# Feature: clientscnt12m_3712952L
# ADF Statistic: -85.897685
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt3m_3712950L
# Feature: clientscnt3m_3712950L
# ADF Statistic: -123.315159
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt6m_3712949L
# Feature: clientscnt6m_3712949L
# ADF Statistic: -123.622093
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_100L
# Feature: clientscnt_100L
# ADF Statistic: -124.987975
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_1022L
# Feature: clientscnt_1022L
# ADF Statistic: -124.235088
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_1071L
# Feature: clientscnt_1071L
# ADF Statistic: -123.347921
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_1130L
# Feature: clientscnt_1130L
# ADF Statistic: -53.281240
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_157L
# Feature: clientscnt_157L
# ADF Statistic: -49.215754
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_257L
# Feature: clientscnt_257L
# ADF Statistic: -123.867344
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_304L
# Feature: clientscnt_304L
# ADF Statistic: -124.292423
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_360L
# Feature: clientscnt_360L
# ADF Statistic: -68.455343
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_493L
# Feature: clientscnt_493L
# ADF Statistic: -123.607273
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_533L
# Feature: clientscnt_533L
# ADF Statistic: -89.156396
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_887L
# Feature: clientscnt_887L
# ADF Statistic: -121.549306
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# clientscnt_946L
# Feature: clientscnt_946L
# ADF Statistic: -123.822670
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# cntincpaycont9m_3716944L
# Feature: cntincpaycont9m_3716944L
# ADF Statistic: -58.586243
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# cntpmts24_3658933L
# Feature: cntpmts24_3658933L
# ADF Statistic: -74.232424
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# commnoinclast6m_3546845L
# Feature commnoinclast6m_3546845L failed due to an error: Invalid input, x is constant
# credamount_770A
# Feature: credamount_770A
# ADF Statistic: -124.372732
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# currdebt_22A
# Feature: currdebt_22A
# ADF Statistic: -124.426503
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# currdebtcredtyperange_828A
# Feature: currdebtcredtyperange_828A
# ADF Statistic: -123.609750
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# datefirstoffer_1144D
# Feature: datefirstoffer_1144D
# ADF Statistic: -82.031035
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# datelastinstal40dpd_247D
# Feature: datelastinstal40dpd_247D
# ADF Statistic: -35.919087
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# データは定常と判断されます。
#
# datelastunpaid_3546854D
# Feature: datelastunpaid_3546854D
# ADF Statistic: -48.070923
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# daysoverduetolerancedd_3976961L
# Feature: daysoverduetolerancedd_3976961L
# ADF Statistic: -34.184141
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# deferredmnthsnum_166L
# Feature deferredmnthsnum_166L failed due to an error: Invalid input, x is constant
# disbursedcredamount_1113A
# Feature: disbursedcredamount_1113A
# ADF Statistic: -123.932306
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# downpmt_116A
# Feature: downpmt_116A
# ADF Statistic: -124.771219
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# dtlastpmtallstes_4499206D
# Feature: dtlastpmtallstes_4499206D
# ADF Statistic: -74.158267
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# eir_270L
# Feature: eir_270L
# ADF Statistic: -114.347290
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# firstclxcampaign_1125D
# Feature: firstclxcampaign_1125D
# ADF Statistic: -80.466733
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# firstdatedue_489D
# Feature: firstdatedue_489D
# ADF Statistic: -102.471637
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# homephncnt_628L
# Feature: homephncnt_628L
# ADF Statistic: -122.833366
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# inittransactionamount_650A
# Feature: inittransactionamount_650A
# ADF Statistic: -44.878332
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
#
# interestrate_311L
# Feature: interestrate_311L
# ADF Statistic: -114.347290
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# isbidproduct_1095L
# Feature: isbidproduct_1095L
# ADF Statistic: -51.601712
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastactivateddate_801D
# Feature: lastactivateddate_801D
# ADF Statistic: -102.850913
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastapplicationdate_877D
# Feature: lastapplicationdate_877D
# ADF Statistic: -110.123580
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastapprcredamount_781A
# Feature: lastapprcredamount_781A
# ADF Statistic: -62.113064
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastapprdate_640D
# Feature: lastapprdate_640D
# ADF Statistic: -103.579577
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastdelinqdate_224D
# Feature: lastdelinqdate_224D
# ADF Statistic: -38.860437
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastrejectcredamount_222A
# Feature: lastrejectcredamount_222A
# ADF Statistic: -87.668032
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# lastrejectdate_50D
# Feature: lastrejectdate_50D
# ADF Statistic: -85.792100
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maininc_215A
# Feature: maininc_215A
# ADF Statistic: -101.673921
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# mastercontrelectronic_519L
# Feature mastercontrelectronic_519L failed due to an error: Invalid input, x is constant
# mastercontrexist_109L
# Feature mastercontrexist_109L failed due to an error: Invalid input, x is constant
# maxannuity_159A
# Feature: maxannuity_159A
# ADF Statistic: -77.173003
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdbddpdlast1m_3658939P
# Feature: maxdbddpdlast1m_3658939P
# ADF Statistic: -75.799076
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdbddpdtollast12m_3658940P
# Feature: maxdbddpdtollast12m_3658940P
# ADF Statistic: -63.040610
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdbddpdtollast6m_4187119P
# Feature: maxdbddpdtollast6m_4187119P
# ADF Statistic: -80.751626
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdebt4_972A
# Feature: maxdebt4_972A
# ADF Statistic: -80.200782
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdfrom6mto36m_3546853P
# Feature: maxdpdfrom6mto36m_3546853P
# ADF Statistic: -110.130132
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdinstldate_3546855D
# Feature: maxdpdinstldate_3546855D
# ADF Statistic: -42.088217
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdinstlnum_3546846P
# Feature: maxdpdinstlnum_3546846P
# ADF Statistic: -58.113273
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdlast12m_727P
# Feature: maxdpdlast12m_727P
# ADF Statistic: -77.431880
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdlast24m_143P
# Feature: maxdpdlast24m_143P
# ADF Statistic: -111.779672
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdlast3m_392P
# Feature: maxdpdlast3m_392P
# ADF Statistic: -111.014312
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdlast6m_474P
# Feature: maxdpdlast6m_474P
# ADF Statistic: -76.463385
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdlast9m_1059P
# Feature: maxdpdlast9m_1059P
# ADF Statistic: -76.828199
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxdpdtolerance_374P
# Feature: maxdpdtolerance_374P
# ADF Statistic: -111.263098
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxinstallast24m_3658928A
# Feature: maxinstallast24m_3658928A
# ADF Statistic: -95.499946
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxlnamtstart6m_4525199A
# Feature: maxlnamtstart6m_4525199A
# ADF Statistic: -71.960363
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxoutstandbalancel12m_4187113A
# Feature: maxoutstandbalancel12m_4187113A
# ADF Statistic: -89.978547
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# maxpmtlast3m_4525190A
# Feature: maxpmtlast3m_4525190A
# ADF Statistic: -36.955039
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# mindbddpdlast24m_3658935P
# Feature: mindbddpdlast24m_3658935P
# ADF Statistic: -96.758143
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# mindbdtollast24m_4525191P
# Feature: mindbdtollast24m_4525191P
# ADF Statistic: -75.234896
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# mobilephncnt_593L
# Feature: mobilephncnt_593L
# ADF Statistic: -124.450801
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# monthsannuity_845L
# Feature: monthsannuity_845L
# ADF Statistic: -102.332117
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numactivecreds_622L
# Feature: numactivecreds_622L
# ADF Statistic: -85.934583
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numactivecredschannel_414L
# Feature: numactivecredschannel_414L
# ADF Statistic: -85.075036
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numactiverelcontr_750L
# Feature: numactiverelcontr_750L
# ADF Statistic: -124.155476
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numcontrs3months_479L
# Feature: numcontrs3months_479L
# ADF Statistic: -37.465687
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numincomingpmts_3546848L
# Feature: numincomingpmts_3546848L
# ADF Statistic: -102.453223
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstlallpaidearly3d_817L
# Feature: numinstlallpaidearly3d_817L
# ADF Statistic: -45.639506
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstls_657L
# Feature: numinstls_657L
# ADF Statistic: -88.276149
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstlsallpaid_934L
# Feature: numinstlsallpaid_934L
# ADF Statistic: -102.870932
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstlswithdpd10_728L
# Feature: numinstlswithdpd10_728L
# ADF Statistic: -102.589804
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstlswithdpd5_4187116L
# Feature: numinstlswithdpd5_4187116L
# ADF Statistic: -97.770364
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstlswithoutdpd_562L
# Feature: numinstlswithoutdpd_562L
# ADF Statistic: -45.254028
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstmatpaidtearly2d_4499204L
# Feature: numinstmatpaidtearly2d_4499204L
# ADF Statistic: -81.182139
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaid_4499208L
# Feature: numinstpaid_4499208L
# ADF Statistic: -81.660100
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly3d_3546850L
# Feature: numinstpaidearly3d_3546850L
# ADF Statistic: -102.256951
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly3dest_4493216L
# Feature: numinstpaidearly3dest_4493216L
# ADF Statistic: -81.573588
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly5d_1087L
# Feature: numinstpaidearly5d_1087L
# ADF Statistic: -102.433180
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly5dest_4493211L
# Feature: numinstpaidearly5dest_4493211L
# ADF Statistic: -83.242436
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly5dobd_4499205L
# Feature: numinstpaidearly5dobd_4499205L
# ADF Statistic: -81.083750
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearly_338L
# Feature: numinstpaidearly_338L
# ADF Statistic: -45.265728
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidearlyest_4493214L
# Feature: numinstpaidearlyest_4493214L
# ADF Statistic: -81.686741
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidlastcontr_4325080L
# Feature: numinstpaidlastcontr_4325080L
# ADF Statistic: -93.714406
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstpaidlate1d_3546852L
# Feature: numinstpaidlate1d_3546852L
# ADF Statistic: -103.002427
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstregularpaid_973L
# Feature: numinstregularpaid_973L
# ADF Statistic: -102.854682
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstregularpaidest_4493210L
# Feature: numinstregularpaidest_4493210L
# ADF Statistic: -82.139118
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinsttopaygr_769L
# Feature: numinsttopaygr_769L
# ADF Statistic: -46.661126
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinsttopaygrest_4493213L
# Feature: numinsttopaygrest_4493213L
# ADF Statistic: -46.978578
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstunpaidmax_3546851L
# Feature: numinstunpaidmax_3546851L
# ADF Statistic: -46.719862
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numinstunpaidmaxest_4493212L
# Feature: numinstunpaidmaxest_4493212L
# ADF Statistic: -46.830546
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numnotactivated_1143L
# Feature: numnotactivated_1143L
# ADF Statistic: -124.648826
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numpmtchanneldd_318L
# Feature: numpmtchanneldd_318L
# ADF Statistic: -124.632380
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# numrejects9m_859L
# Feature: numrejects9m_859L
# ADF Statistic: -48.265356
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pctinstlsallpaidearl3d_427L
# Feature: pctinstlsallpaidearl3d_427L
# ADF Statistic: -28.966915
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pctinstlsallpaidlat10d_839L
# Feature: pctinstlsallpaidlat10d_839L
# ADF Statistic: -103.684820
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pctinstlsallpaidlate1d_3546856L
# Feature: pctinstlsallpaidlate1d_3546856L
# ADF Statistic: -72.310412
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pctinstlsallpaidlate4d_3546849L
# Feature: pctinstlsallpaidlate4d_3546849L
# ADF Statistic: -103.865372
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pctinstlsallpaidlate6d_3546844L
# Feature: pctinstlsallpaidlate6d_3546844L
# ADF Statistic: -103.647960
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# pmtnum_254L
# Feature: pmtnum_254L
# ADF Statistic: -121.733719
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# posfpd10lastmonth_333P
# Feature: posfpd10lastmonth_333P
# ADF Statistic: -121.089186
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# posfpd30lastmonth_3976960P
# Feature: posfpd30lastmonth_3976960P
# ADF Statistic: -118.852616
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# posfstqpd30lastmonth_3976962P
# Feature: posfstqpd30lastmonth_3976962P
# ADF Statistic: -114.823143
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# price_1097A
# Feature: price_1097A
# ADF Statistic: -115.153458
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# sellerplacecnt_915L
# Feature: sellerplacecnt_915L
# ADF Statistic: -123.215900
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# sellerplacescnt_216L
# Feature: sellerplacescnt_216L
# ADF Statistic: -40.409343
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# sumoutstandtotal_3546847A
# Feature: sumoutstandtotal_3546847A
# ADF Statistic: -75.205831
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# sumoutstandtotalest_4493215A
# Feature: sumoutstandtotalest_4493215A
# ADF Statistic: -84.702700
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# totaldebt_9A
# Feature: totaldebt_9A
# ADF Statistic: -124.421553
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# totalsettled_863A
# Feature: totalsettled_863A
# ADF Statistic: -122.429960
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# totinstallast1m_4525188A
# Feature: totinstallast1m_4525188A
# ADF Statistic: -60.027049
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# データは定常と判断されます。
#
# validfrom_1069D
# Feature: validfrom_1069D
# ADF Statistic: -39.265114
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.863
# 	10%: -2.568
# データは定常と判断されます。
# 0

# %%
from statsmodels.tsa.stattools import kpss

result = kpss(data)
print('KPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[3].items():
    print('\t%s: %.3f' % (key, value))

# KPSS統計量とp値を評価して定常性を判断
if result[1] < 0.05:
    print("データは非定常と判断されます。")
else:
    print("データは定常と判断されます。")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 from statsmodels.tsa.stattools import kpss
# ----> 3 result = kpss(data)
#       4 print('KPSS Statistic: %f' % result[0])
#       5 print('p-value: %f' % result[1])
#
# NameError: name 'data' is not defined
